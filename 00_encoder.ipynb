# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# default_exp encoder

# %% [markdown]
# # Imports
#
# > API details.

# %%
#hide
from nbdev.showdoc import *
from fastcore.test import *

# %%
#export
import pandas as pd # package for high-performance, easy-to-use data structures and data analysis
import numpy as np # fundamental package for scientific computing with Python
import matplotlib
import matplotlib.pyplot as plt # for plotting

import re

import string
import gc

from fastai2.basics import *
from fastai2.text.all import *
from fastai2.callback.all import *

# %%
#export
import os
print(os.listdir("../data/gquest_data/"))
data_path = Path("../data/gquest_data/")
# Out:
# ['sample_submission.csv', 'train', 'test']

# %%
import pdb

# %% [markdown]
# # Reading data

# %%
#export
print('Reading data...')
train_data = pd.read_csv(data_path/'train/train.csv')
test_data = pd.read_csv(data_path/'test/test.csv')
sample_submission = pd.read_csv(str(data_path/'sample_submission.csv'))
print('Reading data completed')
# Out:
# Reading data...
# Reading data completed

# %%
#export
print('Size of train_data', train_data.shape)
print('Size of test_data', test_data.shape)
print('Size of sample_submission', sample_submission.shape)
test_eq(train_data.shape,(6079,41))
test_eq(test_data.shape,(476,11))
test_eq(sample_submission.shape,(476,31))
# Out:
# Size of train_data (6079, 41)
# Size of test_data (476, 11)
# Size of sample_submission (476, 31)

# %%
train_data.head()
# Out:
#    qa_id  \
# 0      0
# 1      1
# 2      2
# 3      3
# 4      5
#
#                                                                                                  question_title  \
# 0                                          What am I losing when using extension tubes instead of a macro lens?
# 1  What is the distinction between a city and a sprawl/metroplex... between downtown and a commercial district?
# 2                                                      Maximum protusion length for through-hole component pins
# 3                                                                         Can an affidavit be used in Beit Din?
# 4                                                                  How do you make a binary image in Photoshop?
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              question_body  \
# 0  After playing around with macro photography on-the-cheap (read: reversed lens, rev. lens mounted on a straight lens, passive extension tubes), I would like to get further with this. The problems with the techniques I used is that focus is manual and aperture control is problematic at best. This limited my setup to still subjects (read: dead insects) Now, as spring is approaching, I want to be able to shoot live insects. I believe that for this, autofocus and settable aperture will be of great help.\n\nSo, one obvious but expensive option is a macro lens (say, EF 100mm Macro) However, I am ...
# 1  I am trying to understand what kinds of places the spam values on p 231 refer to in the 5th Edition main book for Shadowrun.\n\nPer p 15, a sprawl is a plex, a plex is a "metropolitan complex, short for metroplex". Per Google a metroplex is " a very large metropolitan area, especially one that is an aggregation of two or more cities".  A city downtown and sprawl downtown would tend to have similar densities, but for some reason the sprawl (which includes suburbs?) has a higher spam zone noise rating (p 231).  Similarly, I'd think of a downtown as being more dense and noisy (e.g. Office bui...
# 2  I'm working on a PCB that has through-hole components on both sides of the board. The "top" side of the board is mounted flush to a Delrin plastic block (the only top-side component is a gas sensor that is fed air samples through hose fittings in the plastic block).\n\nThe flush mounting means that I have to add grooves to the plastic block to accommodate the soldered pins of the bottom-side components. Assuming a standard 0.062" thickness FR4 board, how deep do I need to make the grooves in the plastic block? The only thing I could find is this NASA workmanship standard that states 0.5mm ...
# 3                                                                                                                                                                           An affidavit, from what i understand, is basically a signed document given by a witness to be used as evidence in a trial, without the witness themselves needing to take a stand.\n\nCan an affidavit be used in Beit Din? Or must witnesses take the stand in person for their testimony to count?\n\n(In case i'm misunderstanding what exactly an affidavit is, simply treat it as a signed document by a witness with their testimony.)\n
# 4                                                                                                                                                                                    I am trying to make a binary image. I want more than just the look of the image to be black/white, but I want the actual file to be a binary file. Every pixel should be either black, or white. \n\nI don't just want a monochrome image. I can't have varying shades of gray, every pixel needs to be black or white.\n\nIs this possible? I looked under Image > Mode but nothing there seems to indiciate a binary style image.\n
#
#   question_user_name                                   question_user_page  \
# 0               ysap           https://photo.stackexchange.com/users/1024
# 1      russellpierce             https://rpg.stackexchange.com/users/8774
# 2          Joe Baker    https://electronics.stackexchange.com/users/10157
# 3         Scimonster         https://judaism.stackexchange.com/users/5151
# 4            leigero  https://graphicdesign.stackexchange.com/users/21313
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     answer  \
# 0  I just got extension tubes, so here's the skinny.\n\n\n  ...what am I losing when using tubes...?\n\n\nA very considerable amount of light!  Increasing that distance from the end of the lens to the sensor can cut your light several stops.  Combined with the fact that you'll usually shoot stopped down - expect to need to increase your ISO considerably.\n\nThe fact the macro's are usually considered very very sharp, although I believe that 70-200mm 2.8 is supposed to be quite sharp.\n\nThe ultra low distortion typical of many macros.\n\nI wouldn't worry too much about the bokeh since the DOF...
# 1                                                                                                                                                 It might be helpful to look into the definition of spam zone:\n\n(p.216) spam zone: An area flooded with invasive and/or viral AR advertising, causing noise.\n\nBecause a metroplex has so many marketing targets, it seems a safe assumption that marketers would drown the plex with spam. Spam from the less dense areas would bleed into the urban cores. A smaller city with less urban/suburban territory surrounding it ostensibly wouldn't have as much spam.\n
# 2  Do you even need grooves?  We make several products using through-hole components that are intended to mount using VHB double-sided foam tape.  The boards are 0.062" thick double-sided with PTH and we use a table-top vertical belt sander to bring the component leads almost flush with the solder mask.  In other words, the solder mask isn't touched by the sand paper but the leads are all sanded flat and sitting just proud of the solder mask.\n\nThis works well for small boards.\n\nFor what it's worth, there are commercial machines available that use a rotary saw blade to do the same thing.  ...
# 3  Sending an "affidavit" it is a dispute between Rashi and Rabbeinu Tam.\n\nDevarim 19:15:\n\n\n  לא יקום עד אחד באיש לכל עון ולכל חטאת בכל חטא אשר יחטא על פי שני עדים או על פי שלשה עדים יקום דבר\n\n\nRashi:\n\n\n  ולא שיכתבו עדותם באגרת וישלחו לבית דין\n  \n  And not that they write their testimony in a letter and send it to Beis Din\n\n\nTosefos Bava Basra 40a (continued from 39b):\n\n\n  ועוד אומר ר"י ששמע מן ר"ת שנוהגים לשלח העדים עדותם באיגרת לב"ד וחשיב עדות והא דדרשינן בספרי. מפיהם ולא מפי כתבם לא אתא אלא למעוטי דוקא אלם שאינו בר הגדה אבל ראוי להגדה אין הגדה מעכבת בו \n  \n  R"i said t...
# 4                                                                                                                                                                                                                                                                                                                                                                               Check out Image Trace in Adobe Illustrator. \n\nI like using python and PIL, however.\n\nfrom PIL import Image\nimage_file = Image.open("myimage.bmp") \nimage_file = image_file.convert('1') # convert\nimage_file.save('result.bmp')\n\n
#
#   answer_user_name                                     answer_user_page  \
# 0           rfusca           https://photo.stackexchange.com/users/1917
# 1     Erik Schmidt             https://rpg.stackexchange.com/users/1871
# 2      Dwayne Reid    https://electronics.stackexchange.com/users/64754
# 3    Y     e     z         https://judaism.stackexchange.com/users/4794
# 4             q2ra  https://graphicdesign.stackexchange.com/users/27160
#
#                                                                                                                           url  \
# 0           http://photo.stackexchange.com/questions/9169/what-am-i-losing-when-using-extension-tubes-instead-of-a-macro-lens
# 1  http://rpg.stackexchange.com/questions/47820/what-is-the-distinction-between-a-city-and-a-sprawl-metroplex-between-downtow
# 2              http://electronics.stackexchange.com/questions/154225/maximum-protusion-length-for-through-hole-component-pins
# 3                                       http://judaism.stackexchange.com/questions/55182/can-an-affidavit-be-used-in-beit-din
# 4                          http://graphicdesign.stackexchange.com/questions/35791/how-do-you-make-a-binary-image-in-photoshop
#
#     category  ... question_well_written  answer_helpful  \
# 0  LIFE_ARTS  ...              1.000000        1.000000
# 1    CULTURE  ...              0.888889        0.888889
# 2    SCIENCE  ...              0.777778        0.777778
# 3    CULTURE  ...              0.888889        0.833333
# 4  LIFE_ARTS  ...              1.000000        1.000000
#
#    answer_level_of_information  answer_plausible  answer_relevance  \
# 0                     0.666667          1.000000          1.000000
# 1                     0.555556          0.888889          0.888889
# 2                     0.555556          1.000000          1.000000
# 3                     0.333333          0.833333          1.000000
# 4                     0.666667          1.000000          1.000000
#
#    answer_satisfaction  answer_type_instructions  answer_type_procedure  \
# 0             0.800000                       1.0               0.000000
# 1             0.666667                       0.0               0.000000
# 2             0.666667                       0.0               0.333333
# 3             0.800000                       0.0               0.000000
# 4             0.800000                       1.0               0.000000
#
#    answer_type_reason_explanation  answer_well_written
# 0                        0.000000             1.000000
# 1                        0.666667             0.888889
# 2                        1.000000             0.888889
# 3                        1.000000             1.000000
# 4                        1.000000             1.000000
#
# [5 rows x 41 columns]

# %%
train_data.columns
# Out:
# Index(['qa_id', 'question_title', 'question_body', 'question_user_name',
#        'question_user_page', 'answer', 'answer_user_name', 'answer_user_page',
#        'url', 'category', 'host', 'question_asker_intent_understanding',
#        'question_body_critical', 'question_conversational',
#        'question_expect_short_answer', 'question_fact_seeking',
#        'question_has_commonly_accepted_answer',
#        'question_interestingness_others', 'question_interestingness_self',
#        'question_multi_intent', 'question_not_really_a_question',
#        'question_opinion_seeking', 'question_type_choice',
#        'question_type_compare', 'question_type_consequence',
#        'question_type_definition', 'question_type_entity',
#        'question_type_instructions', 'question_type_procedure',
#        'question_type_reason_explanation', 'question_type_spelling',
#        'question_well_written', 'answer_helpful',
#        'answer_level_of_information', 'answer_plausible', 'answer_relevance',
#        'answer_satisfaction', 'answer_type_instructions',
#        'answer_type_procedure', 'answer_type_reason_explanation',
#        'answer_well_written'],
#       dtype='object')

# %%
sample_submission.columns
# Out:
# Index(['qa_id', 'question_asker_intent_understanding',
#        'question_body_critical', 'question_conversational',
#        'question_expect_short_answer', 'question_fact_seeking',
#        'question_has_commonly_accepted_answer',
#        'question_interestingness_others', 'question_interestingness_self',
#        'question_multi_intent', 'question_not_really_a_question',
#        'question_opinion_seeking', 'question_type_choice',
#        'question_type_compare', 'question_type_consequence',
#        'question_type_definition', 'question_type_entity',
#        'question_type_instructions', 'question_type_procedure',
#        'question_type_reason_explanation', 'question_type_spelling',
#        'question_well_written', 'answer_helpful',
#        'answer_level_of_information', 'answer_plausible', 'answer_relevance',
#        'answer_satisfaction', 'answer_type_instructions',
#        'answer_type_procedure', 'answer_type_reason_explanation',
#        'answer_well_written'],
#       dtype='object')

# %%
targets = list(sample_submission.columns[1:])
targets
# Out:
# ['question_asker_intent_understanding',
#  'question_body_critical',
#  'question_conversational',
#  'question_expect_short_answer',
#  'question_fact_seeking',
#  'question_has_commonly_accepted_answer',
#  'question_interestingness_others',
#  'question_interestingness_self',
#  'question_multi_intent',
#  'question_not_really_a_question',
#  'question_opinion_seeking',
#  'question_type_choice',
#  'question_type_compare',
#  'question_type_consequence',
#  'question_type_definition',
#  'question_type_entity',
#  'question_type_instructions',
#  'question_type_procedure',
#  'question_type_reason_explanation',
#  'question_type_spelling',
#  'question_well_written',
#  'answer_helpful',
#  'answer_level_of_information',
#  'answer_plausible',
#  'answer_relevance',
#  'answer_satisfaction',
#  'answer_type_instructions',
#  'answer_type_procedure',
#  'answer_type_reason_explanation',
#  'answer_well_written']

# %%
text_columns=['question_title', 'question_body', 'question_user_name',
       'question_user_page', 'answer', 'answer_user_name', 'answer_user_page',
       'url', 'category', 'host']

# %%
train_data[targets].describe()
# Out:
#        question_asker_intent_understanding  question_body_critical  \
# count                          6079.000000             6079.000000
# mean                              0.892663                0.595301
# std                               0.132047                0.219470
# min                               0.333333                0.333333
# 25%                               0.777778                0.444444
# 50%                               0.888889                0.555556
# 75%                               1.000000                0.777778
# max                               1.000000                1.000000
#
#        question_conversational  question_expect_short_answer  \
# count              6079.000000                   6079.000000
# mean                  0.057301                      0.698525
# std                   0.182196                      0.350938
# min                   0.000000                      0.000000
# 25%                   0.000000                      0.500000
# 50%                   0.000000                      0.666667
# 75%                   0.000000                      1.000000
# max                   1.000000                      1.000000
#
#        question_fact_seeking  question_has_commonly_accepted_answer  \
# count            6079.000000                            6079.000000
# mean                0.772633                               0.793689
# std                 0.303023                               0.336622
# min                 0.000000                               0.000000
# 25%                 0.666667                               0.666667
# 50%                 1.000000                               1.000000
# 75%                 1.000000                               1.000000
# max                 1.000000                               1.000000
#
#        question_interestingness_others  question_interestingness_self  \
# count                      6079.000000                    6079.000000
# mean                          0.587478                       0.507275
# std                           0.135900                       0.185987
# min                           0.333333                       0.333333
# 25%                           0.444444                       0.333333
# 50%                           0.555556                       0.444444
# 75%                           0.666667                       0.666667
# max                           1.000000                       1.000000
#
#        question_multi_intent  question_not_really_a_question  ...  \
# count            6079.000000                     6079.000000  ...
# mean                0.238745                        0.004469  ...
# std                 0.335057                        0.045782  ...
# min                 0.000000                        0.000000  ...
# 25%                 0.000000                        0.000000  ...
# 50%                 0.000000                        0.000000  ...
# 75%                 0.333333                        0.000000  ...
# max                 1.000000                        1.000000  ...
#
#        question_well_written  answer_helpful  answer_level_of_information  \
# count            6079.000000     6079.000000                  6079.000000
# mean                0.799931        0.925408                     0.654823
# std                 0.178420        0.114836                     0.107666
# min                 0.333333        0.333333                     0.333333
# 25%                 0.666667        0.888889                     0.666667
# 50%                 0.833333        1.000000                     0.666667
# 75%                 1.000000        1.000000                     0.666667
# max                 1.000000        1.000000                     1.000000
#
#        answer_plausible  answer_relevance  answer_satisfaction  \
# count       6079.000000       6079.000000          6079.000000
# mean           0.960054          0.968626             0.854680
# std            0.086926          0.074631             0.130743
# min            0.333333          0.333333             0.200000
# 25%            1.000000          1.000000             0.800000
# 50%            1.000000          1.000000             0.866667
# 75%            1.000000          1.000000             0.933333
# max            1.000000          1.000000             1.000000
#
#        answer_type_instructions  answer_type_procedure  \
# count               6079.000000            6079.000000
# mean                   0.479547               0.130641
# std                    0.422921               0.225718
# min                    0.000000               0.000000
# 25%                    0.000000               0.000000
# 50%                    0.500000               0.000000
# 75%                    1.000000               0.333333
# max                    1.000000               1.000000
#
#        answer_type_reason_explanation  answer_well_written
# count                     6079.000000          6079.000000
# mean                         0.502468             0.908254
# std                          0.407097             0.100708
# min                          0.000000             0.333333
# 25%                          0.000000             0.888889
# 50%                          0.500000             0.888889
# 75%                          1.000000             1.000000
# max                          1.000000             1.000000
#
# [8 rows x 30 columns]

# %%
train_data['question_body'][0]
# Out:
# 'After playing around with macro photography on-the-cheap (read: reversed lens, rev. lens mounted on a straight lens, passive extension tubes), I would like to get further with this. The problems with the techniques I used is that focus is manual and aperture control is problematic at best. This limited my setup to still subjects (read: dead insects) Now, as spring is approaching, I want to be able to shoot live insects. I believe that for this, autofocus and settable aperture will be of great help.\n\nSo, one obvious but expensive option is a macro lens (say, EF 100mm Macro) However, I am not really interested in yet another prime lens. An alternative is the electrical extension tubes.\n\nExcept for maximum focusing distance, what am I losing when using tubes (coupled with a fine lens, say EF70-200/2.8) instead of a macro lens?\n'

# %%
text_columns
# Out:
# ['question_title',
#  'question_body',
#  'question_user_name',
#  'question_user_page',
#  'answer',
#  'answer_user_name',
#  'answer_user_page',
#  'url',
#  'category',
#  'host']

# %%
df_tokenized,token_count=tokenize_df(train_data,text_columns)

# %%
df_tokenized.head()
# Out:
#    qa_id  question_asker_intent_understanding  question_body_critical  \
# 0      0                             1.000000                0.333333
# 1      1                             1.000000                1.000000
# 2      2                             0.888889                0.666667
# 3      3                             0.888889                0.666667
# 4      5                             1.000000                0.666667
#
#    question_conversational  question_expect_short_answer  \
# 0                 0.000000                           0.0
# 1                 0.000000                           0.5
# 2                 0.000000                           1.0
# 3                 0.666667                           1.0
# 4                 0.000000                           1.0
#
#    question_fact_seeking  question_has_commonly_accepted_answer  \
# 0                    0.0                                    0.0
# 1                    1.0                                    1.0
# 2                    1.0                                    1.0
# 3                    1.0                                    1.0
# 4                    1.0                                    1.0
#
#    question_interestingness_others  question_interestingness_self  \
# 0                         1.000000                       1.000000
# 1                         0.444444                       0.444444
# 2                         0.666667                       0.444444
# 3                         0.444444                       0.444444
# 4                         0.666667                       0.666667
#
#    question_multi_intent  ...  answer_helpful  answer_level_of_information  \
# 0               0.000000  ...        1.000000                     0.666667
# 1               0.666667  ...        0.888889                     0.555556
# 2               0.333333  ...        0.777778                     0.555556
# 3               0.000000  ...        0.833333                     0.333333
# 4               0.000000  ...        1.000000                     0.666667
#
#    answer_plausible  answer_relevance  answer_satisfaction  \
# 0          1.000000          1.000000             0.800000
# 1          0.888889          0.888889             0.666667
# 2          1.000000          1.000000             0.666667
# 3          0.833333          1.000000             0.800000
# 4          1.000000          1.000000             0.800000
#
#    answer_type_instructions  answer_type_procedure  \
# 0                       1.0               0.000000
# 1                       0.0               0.000000
# 2                       0.0               0.333333
# 3                       0.0               0.000000
# 4                       1.0               0.000000
#
#    answer_type_reason_explanation  answer_well_written  \
# 0                        0.000000             1.000000
# 1                        0.666667             0.888889
# 2                        1.000000             0.888889
# 3                        1.000000             1.000000
# 4                        1.000000             1.000000
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       text
# 0  [xxbos, xxfld, 1, xxmaj, what, am, i, losing, when, using, extension, tubes, instead, of, a, macro, lens, ?, xxfld, 2, xxmaj, after, playing, around, with, macro, photography, on, -, the, -, cheap, (, read, :, reversed, lens, ,, rev, ., lens, mounted, on, a, straight, lens, ,, passive, extension, tubes, ), ,, i, would, like, to, get, further, with, this, ., xxmaj, the, problems, with, the, techniques, i, used, is, that, focus, is, manual, and, aperture, control, is, problematic, at, best, ., xxmaj, this, limited, my, setup, to, still, subjects, (, read, :, dead, insects, ), xxmaj, now, ,, ...
# 1  [xxbos, xxfld, 1, xxmaj, what, is, the, distinction, between, a, city, and, a, sprawl, /, metroplex, …, between, downtown, and, a, commercial, district, ?, xxfld, 2, i, am, trying, to, understand, what, kinds, of, places, the, spam, values, on, p, 231, refer, to, in, the, 5th, xxmaj, edition, main, book, for, xxmaj, shadowrun, ., \n\n, xxmaj, per, p, 15, ,, a, sprawl, is, a, plex, ,, a, plex, is, a, ", metropolitan, complex, ,, short, for, metroplex, ", ., xxmaj, per, xxmaj, google, a, metroplex, is, ", a, very, large, metropolitan, area, ,, especially, one, that, is, an, aggregation, of, ...
# 2  [xxbos, xxfld, 1, xxmaj, maximum, protusion, length, for, through, -, hole, component, pins, xxfld, 2, xxmaj, i, 'm, working, on, a, xxup, pcb, that, has, through, -, hole, components, on, both, sides, of, the, board, ., xxmaj, the, ", top, ", side, of, the, board, is, mounted, flush, to, a, xxmaj, delrin, plastic, block, (, the, only, top, -, side, component, is, a, gas, sensor, that, is, fed, air, samples, through, hose, fittings, in, the, plastic, block, ), ., \n\n, xxmaj, the, flush, mounting, means, that, i, have, to, add, grooves, to, the, plastic, block, to, accommodate, the, solder...
# 3  [xxbos, xxfld, 1, xxmaj, can, an, affidavit, be, used, in, xxmaj, beit, xxmaj, din, ?, xxfld, 2, xxmaj, an, affidavit, ,, from, what, i, understand, ,, is, basically, a, signed, document, given, by, a, witness, to, be, used, as, evidence, in, a, trial, ,, without, the, witness, themselves, needing, to, take, a, stand, ., \n\n, xxmaj, can, an, affidavit, be, used, in, xxmaj, beit, xxmaj, din, ?, xxmaj, or, must, witnesses, take, the, stand, in, person, for, their, testimony, to, count, ?, \n\n, (, in, case, i, 'm, misunderstanding, what, exactly, an, affidavit, is, ,, simply, treat, it, as,...
# 4                                                     [xxbos, xxfld, 1, xxmaj, how, do, you, make, a, binary, image, in, xxmaj, photoshop, ?, xxfld, 2, i, am, trying, to, make, a, binary, image, ., i, want, more, than, just, the, look, of, the, image, to, be, black, /, white, ,, but, i, want, the, actual, file, to, be, a, binary, file, ., xxmaj, every, pixel, should, be, either, black, ,, or, white, ., \n\n, i, do, n't, just, want, a, monochrome, image, ., i, ca, n't, have, varying, shades, of, gray, ,, every, pixel, needs, to, be, black, or, white, ., \n\n, xxmaj, is, this, possible, ?, i, ...]
#
# [5 rows x 32 columns]

# %%
vocab = make_vocab(token_count)
vocab
# Out:
# ['xxunk',
#  'xxpad',
#  'xxbos',
#  'xxeos',
#  'xxfld',
#  'xxrep',
#  'xxwrep',
#  'xxup',
#  'xxmaj',
#  '/',
#  'the',
#  ',',
#  '-',
#  '.',
#  'to',
#  '\n▁',
#  'a',
#  ':',
#  ')',
#  'i',
#  'is',
#  '\n\n',
#  'and',
#  'of',
#  '"',
#  '(',
#  'in',
#  '\n',
#  'it',
#  'that',
#  '\\',
#  'you',
#  '$',
#  'for',
#  ';',
#  'this',
#  '?',
#  '=',
#  'users',
#  'https',
#  '}',
#  "'",
#  'with',
#  'on',
#  'be',
#  '3',
#  '>',
#  '1',
#  'if',
#  'have',
#  'as',
#  'not',
#  'can',
#  'are',
#  '<',
#  '2',
#  '{',
#  'or',
#  'but',
#  'do',
#  '\n\n\n',
#  '4',
#  'http',
#  '5',
#  'from',
#  'my',
#  "'s",
#  "n't",
#  '10',
#  '6',
#  ']',
#  'an',
#  '7',
#  '8',
#  'questions',
#  '9',
#  '\n\n▁',
#  'so',
#  'how',
#  'what',
#  'at',
#  'your',
#  'there',
#  'will',
#  'would',
#  'stackoverflow.com',
#  'by',
#  'use',
#  'one',
#  'when',
#  'which',
#  'like',
#  'all',
#  '0',
#  'some',
#  'does',
#  '&',
#  'get',
#  'any',
#  'using',
#  'they',
#  'then',
#  '[',
#  'was',
#  '*',
#  'just',
#  'more',
#  '+',
#  'should',
#  'has',
#  'we',
#  'other',
#  'want',
#  '#',
#  "'m",
#  'need',
#  'only',
#  'way',
#  'no',
#  'about',
#  'am',
#  'up',
#  'time',
#  'also',
#  'new',
#  'out',
#  'could',
#  'technology',
#  'code',
#  '…',
#  'where',
#  'me',
#  'make',
#  '!',
#  'file',
#  'here',
#  'same',
#  'than',
#  'them',
#  'know',
#  'into',
#  'work',
#  'two',
#  'set',
#  'data',
#  'see',
#  'because',
#  '\n\n\n▁',
#  'first',
#  'why',
#  'question',
#  'after',
#  'used',
#  'example',
#  'now',
#  'these',
#  'find',
#  'their',
#  'function',
#  '%',
#  '_',
#  'problem',
#  'he',
#  "'ve",
#  'x',
#  'something',
#  'good',
#  'even',
#  'user',
#  'page',
#  'very',
#  'each',
#  'may',
#  'different',
#  'been',
#  'server',
#  'think',
#  'right',
#  'return',
#  'such',
#  'c',
#  'much',
#  'class',
#  'most',
#  'between',
#  'another',
#  'value',
#  'its',
#  'stackoverflow',
#  'add',
#  'since',
#  'list',
#  'did',
#  'go',
#  'however',
#  'still',
#  'error',
#  '|',
#  'string',
#  'number',
#  'name',
#  'd',
#  'help',
#  'case',
#  'without',
#  'possible',
#  'create',
#  'had',
#  'well',
#  'end',
#  'system',
#  'while',
#  'might',
#  'before',
#  'many',
#  'public',
#  'line',
#  'try',
#  'change',
#  'following',
#  'etc',
#  'really',
#  'ca',
#  'through',
#  'say',
#  'being',
#  'take',
#  'over',
#  "'re",
#  'answer',
#  'text',
#  'image',
#  '\n\n\n\n',
#  'who',
#  'both',
#  'people',
#  'table',
#  'files',
#  'point',
#  'int',
#  'culture',
#  'were',
#  'b',
#  'run',
#  'type',
#  'back',
#  'better',
#  'else',
#  'trying',
#  'too',
#  'look',
#  'field',
#  'key',
#  'able',
#  'sure',
#  'off',
#  'start',
#  'english.stackexchange.com',
#  'current',
#  'superuser.com',
#  'going',
#  'read',
#  'best',
#  'seems',
#  'electronics.stackexchange.com',
#  'things',
#  'method',
#  'every',
#  'down',
#  'found',
#  'script',
#  'w',
#  'edit',
#  'access',
#  'left',
#  'application',
#  'site',
#  'serverfault.com',
#  'let',
#  'looking',
#  'his',
#  'those',
#  "'d",
#  'part',
#  'android',
#  'science',
#  'size',
#  'update',
#  'long',
#  'y',
#  '--',
#  'object',
#  'output',
#  'working',
#  'works',
#  'array',
#  'true',
#  'select',
#  'running',
#  'lot',
#  'our',
#  'instead',
#  'form',
#  'check',
#  'show',
#  'php',
#  'windows',
#  'actually',
#  'information',
#  "'ll",
#  'app',
#  'math.stackexchange.com',
#  'order',
#  'word',
#  'though',
#  'give',
#  'second',
#  'put',
#  'thanks',
#  'above',
#  'source',
#  'own',
#  'simple',
#  'less',
#  'version',
#  'tried',
#  'around',
#  'solution',
#  'life_arts',
#  'done',
#  'having',
#  'always',
#  's',
#  'bit',
#  'var',
#  'times',
#  'database',
#  'based',
#  'already',
#  'given',
#  'thing',
#  'again',
#  'power',
#  'call',
#  'either',
#  'values',
#  'post',
#  'probably',
#  'doing',
#  'div',
#  'result',
#  'non',
#  'option',
#  'e',
#  'group',
#  'view',
#  'must',
#  'physics.stackexchange.com',
#  'last',
#  'few',
#  'game',
#  'input',
#  '\n▁\n▁',
#  'never',
#  'open',
#  'means',
#  'link',
#  'null',
#  'level',
#  'mean',
#  'specific',
#  'f',
#  'web',
#  'command',
#  'issue',
#  'write',
#  'understand',
#  '..',
#  'note',
#  'single',
#  'n',
#  'high',
#  'top',
#  'small',
#  'correct',
#  'content',
#  'difference',
#  'please',
#  'someone',
#  'idea',
#  'enough',
#  'getting',
#  'next',
#  'p',
#  'anyone',
#  'multiple',
#  'button',
#  'least',
#  'made',
#  'query',
#  'm',
#  'default',
#  'message',
#  'called',
#  'space',
#  'tex.stackexchange.com',
#  'anything',
#  'once',
#  'install',
#  'similar',
#  'below',
#  'got',
#  'far',
#  't',
#  'side',
#  'device',
#  'service',
#  'us',
#  'said',
#  'keep',
#  'network',
#  'project',
#  'reason',
#  'process',
#  'wrong',
#  'test',
#  'google',
#  'simply',
#  'often',
#  'old',
#  'little',
#  'images',
#  'tell',
#  'main',
#  'column',
#  'path',
#  'remove',
#  'kind',
#  'quite',
#  'display',
#  'voltage',
#  'sql',
#  'static',
#  'usually',
#  'course',
#  'hard',
#  'html',
#  'fine',
#  'askubuntu.com',
#  'programmers.stackexchange.com',
#  'custom',
#  'results',
#  'makes',
#  'available',
#  'under',
#  'r',
#  'rpg.stackexchange.com',
#  'void',
#  'state',
#  'place',
#  'per',
#  'points',
#  'created',
#  'url',
#  'large',
#  'real',
#  'false',
#  'local',
#  'bad',
#  'maybe',
#  'via',
#  'print',
#  'book',
#  'machine',
#  'general',
#  'full',
#  'control',
#  'making',
#  'save',
#  'home',
#  'rather',
#  'reference',
#  'water',
#  'e.g.',
#  'standard',
#  'wo',
#  'g',
#  'free',
#  'click',
#  'log',
#  'inside',
#  'original',
#  'player',
#  'computer',
#  'whether',
#  'java',
#  'product',
#  'energy',
#  'words',
#  'color',
#  '100',
#  'gaming.stackexchange.com',
#  'seem',
#  'map',
#  'fact',
#  'search',
#  'common',
#  'allow',
#  'title',
#  'address',
#  'within',
#  'load',
#  'certain',
#  'design',
#  'model',
#  'unix.stackexchange.com',
#  'him',
#  'likely',
#  'options',
#  'program',
#  'drive',
#  'sense',
#  'memory',
#  'email',
#  'three',
#  'date',
#  'mode',
#  'come',
#  'yes',
#  'looks',
#  'apple.stackexchange.com',
#  'person',
#  'particular',
#  'low',
#  'element',
#  'uses',
#  'block',
#  'private',
#  'package',
#  'consider',
#  'javascript',
#  'says',
#  'client',
#  'until',
#  'security',
#  'everything',
#  'academia.stackexchange.com',
#  'changes',
#  'whole',
#  'photo.stackexchange.com',
#  'store',
#  'settings',
#  'easy',
#  'items',
#  'lines',
#  'several',
#  'ubuntu',
#  'years',
#  'include',
#  'pretty',
#  'software',
#  'domain',
#  'yet',
#  'i.e.',
#  'light',
#  'window',
#  'her',
#  'exactly',
#  'world',
#  'drupal.stackexchange.com',
#  'needs',
#  'variable',
#  'she',
#  'related',
#  'required',
#  'move',
#  'connection',
#  '^',
#  'account',
#  'diy.stackexchange.com',
#  'ux.stackexchange.com',
#  'event',
#  'background',
#  'during',
#  'play',
#  'gets',
#  'password',
#  'instance',
#  'important',
#  'scifi.stackexchange.com',
#  'linux',
#  'send',
#  'item',
#  'directory',
#  'objects',
#  'range',
#  'numbers',
#  'sort',
#  'echo',
#  'screen',
#  'clear',
#  'switch',
#  'force',
#  'import',
#  'setting',
#  'card',
#  'day',
#  'nothing',
#  'great',
#  'body',
#  'security.stackexchange.com',
#  'students',
#  'big',
#  'paper',
#  'build',
#  'mail',
#  'circuit',
#  'python',
#  '12',
#  'ask',
#  'character',
#  'index',
#  'short',
#  'term',
#  'against',
#  'adding',
#  'seen',
#  'normal',
#  'style',
#  'filter',
#  'effect',
#  'reading',
#  'itself',
#  'hand',
#  'disk',
#  'god',
#  '“',
#  'close',
#  'thought',
#  '”',
#  'hit',
#  'meaning',
#  'rules',
#  'position',
#  'turn',
#  'language',
#  'problems',
#  'added',
#  'box',
#  'final',
#  'car',
#  'english',
#  'mm',
#  'ell.stackexchange.com',
#  'fields',
#  'currently',
#  'loop',
#  'sometimes',
#  'others',
#  'api',
#  'functions',
#  '`',
#  'support',
#  'format',
#  'due',
#  'comes',
#  'gamedev.stackexchange.com',
#  'white',
#  'length',
#  'document',
#  'takes',
#  'folder',
#  'methods',
#  'job',
#  'basic',
#  'stop',
#  '20',
#  'mathoverflow.net',
#  'figure',
#  'delete',
#  'website',
#  'fix',
#  'dev',
#  'wordpress.stackexchange.com',
#  'menu',
#  'k',
#  'later',
#  'days',
#  'answers',
#  'os',
#  'choose',
#  'head',
#  'attack',
#  'action',
#  'amount',
#  'bottom',
#  'library',
#  'directly',
#  'company',
#  'matter',
#  'copy',
#  'especially',
#  'thus',
#  'needed',
#  'although',
#  'magento.stackexchange.com',
#  'comment',
#  'elements',
#  'gives',
#  'ip',
#  'year',
#  'vector',
#  'mechanics.stackexchange.com',
#  'node',
#  'ok',
#  'area',
#  'creating',
#  'assume',
#  'speed',
#  'bytes',
#  'def',
#  'z',
#  'installed',
#  'pi',
#  'away',
#  'sound',
#  'stack',
#  'provide',
#  'black',
#  'graphicdesign.stackexchange.com',
#  'root',
#  'therefore',
#  'links',
#  'row',
#  'td',
#  'across',
#  'engine',
#  'shows',
#  'pages',
#  'front',
#  'pass',
#  'terms',
#  'approach',
#  'bicycles.stackexchange.com',
#  'money.stackexchange.com',
#  'connected',
#  'zero',
#  'insert',
#  'xml',
#  'cause',
#  'feel',
#  'examples',
#  'property',
#  'goes',
#  'experience',
#  'module',
#  'stuff',
#  'camera',
#  'research',
#  'rest',
#  'rule',
#  'none',
#  'ways',
#  'connect',
#  'apply',
#  'properties',
#  'remember',
#  'section',
#  'useful',
#  'complete',
#  'performance',
#  'money',
#  'mysql',
#  'signal',
#  'completely',
#  'according',
#  'port',
#  'travel.stackexchange.com',
#  'mathematica.stackexchange.com',
#  'cases',
#  'label',
#  'total',
#  'started',
#  '11',
#  'draw',
#  'comments',
#  'basically',
#  'longer',
#  'revision',
#  'context',
#  'known',
#  'replace',
#  'higher',
#  'configuration',
#  'response',
#  'defined',
#  'whatever',
#  'hash',
#  'article',
#  'gis.stackexchange.com',
#  'h',
#  'session',
#  'perhaps',
#  'browser',
#  'guess',
#  'thinking',
#  'changed',
#  'missing',
#  'buy',
#  'count',
#  'manager',
#  'programming',
#  'lens',
#  'actual',
#  'template',
#  'starting',
#  'dba.stackexchange.com',
#  'avoid',
#  'feature',
#  'boardgames.stackexchange.com',
#  'cooking.stackexchange.com',
#  'request',
#  'step',
#  'double',
#  'allows',
#  'damage',
#  'generally',
#  'sudo',
#  'handle',
#  'css',
#  'contains',
#  'red',
#  'setup',
#  'happens',
#  'business',
#  'self',
#  'law',
#  'changing',
#  'games',
#  'otherwise',
#  'extra',
#  'tool',
#  'judaism.stackexchange.com',
#  'unless',
#  'special',
#  're',
#  'parts',
#  '15',
#  'desktop',
#  'theory',
#  'hope',
#  'frame',
#  '30',
#  'existing',
#  'jquery',
#  'online',
#  'playing',
#  'info',
#  'music.stackexchange.com',
#  'solve',
#  'boot',
#  'believe',
#  'statement',
#  'issues',
#  'choice',
#  'outside',
#  'languages',
#  'random',
#  'easier',
#  'room',
#  'books',
#  'cost',
#  'suggest',
#  'plugin',
#  'wondering',
#  'players',
#  'sharepoint.stackexchange.com',
#  'correctly',
#  'v',
#  'selected',
#  'follow',
#  'require',
#  'mind',
#  'bike',
#  'distance',
#  'devices',
#  'present',
#  '50',
#  'easily',
#  'child',
#  'explain',
#  'almost',
#  'rate',
#  'vs',
#  'bin',
#  'further',
#  'writing',
#  'written',
#  'asked',
#  'applications',
#  'depends',
#  'house',
#  'probability',
#  'tree',
#  'define',
#  'live',
#  'couple',
#  'contain',
#  'minutes',
#  'john',
#  'determine',
#  'login',
#  'break',
#  'exception',
#  'ones',
#  'environment',
#  'returns',
#  'meta.stackexchange.com',
#  'tag',
#  'battery',
#  'variables',
#  'separate',
#  'classes',
#  'usr',
#  'price',
#  'location',
#  'phone',
#  'asking',
#  'task',
#  'fixed',
#  'expect',
#  'recently',
#  'happen',
#  'types',
#  'ideas',
#  'base',
#  'along',
#  'structure',
#  'various',
#  'width',
#  'columns',
#  '2013',
#  'life',
#  'thread',
#  'sentence',
#  'previous',
#  'empty',
#  '’s',
#  'limit',
#  'host',
#  'details',
#  'volume',
#  'situation',
#  'assuming',
#  'future',
#  'names',
#  'deal',
#  'download',
#  'series',
#  'wanted',
#  'sites',
#  'usb',
#  'moving',
#  'customer',
#  'depending',
#  'christianity.stackexchange.com',
#  'l',
#  'negative',
#  'specifically',
#  'share',
#  'mark',
#  'layer',
#  'taking',
#  'equivalent',
#  'came',
#  'mac',
#  'including',
#  'li',
#  'considered',
#  'definition',
#  'gb',
#  'match',
#  'mentioned',
#  '200',
#  'additional',
#  'bar',
#  'oil',
#  'necessary',
#  'positive',
#  'automatically',
#  'together',
#  'prevent',
#  'ever',
#  'tools',
#  'earth',
#  'chain',
#  'learn',
#  'algorithm',
#  '24',
#  'keys',
#  ...]

# %%
tfm = Numericalize(make_vocab(token_count))

# %%
splits = RandomSplitter()(df_tokenized)

# %%
splits
# Out:
# ((#4864) [1735,4260,2532,4799,2540,4188,5082,2306,917,5798...],
#  (#1215) [4004,4741,2904,3900,330,3617,1731,5896,306,5912...])

# %%
dsrc = DataSource(df_tokenized, [[attrgetter("text"), tfm]], splits=splits, dl_type=LMDataLoader)

# %%
bs,sl = 50,300
dbch = dsrc.databunch(bs=bs, seq_len=sl, after_batch=Cuda)

# %%
dbch.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#       <th>text_</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>xxbos xxfld 1 xxmaj recursive settimeout in javascript xxfld 2 xxmaj is it possible to run this " indefinitely " , without causing stack overflow or running out of memory ? \n\n function eternal ( ) { \n▁ var time = xxunk ( ) ; \n▁ xxunk ( ) ; \n▁ xxunk , time ) ; \n } \n\n xxunk xxrep 5 0 ) ; \n\n\n xxmaj i 'm not using xxunk , because the triggering time is variable . \n▁ xxfld 3 xxmaj xxunk xxmaj xxunk xxfld 4 https : / / stackoverflow.com / users / xxunk xxfld 5 xxmaj this is not actually a recursive call because the first invocation of eternal ( ) has actually finished before the settimeout ( ) calls the next one . xxmaj so , it 's not technically recursion and does not build up the stack over time . xxmaj it can</td>
#       <td>xxfld 1 xxmaj recursive settimeout in javascript xxfld 2 xxmaj is it possible to run this " indefinitely " , without causing stack overflow or running out of memory ? \n\n function eternal ( ) { \n▁ var time = xxunk ( ) ; \n▁ xxunk ( ) ; \n▁ xxunk , time ) ; \n } \n\n xxunk xxrep 5 0 ) ; \n\n\n xxmaj i 'm not using xxunk , because the triggering time is variable . \n▁ xxfld 3 xxmaj xxunk xxmaj xxunk xxfld 4 https : / / stackoverflow.com / users / xxunk xxfld 5 xxmaj this is not actually a recursive call because the first invocation of eternal ( ) has actually finished before the settimeout ( ) calls the next one . xxmaj so , it 's not technically recursion and does not build up the stack over time . xxmaj it can run forever without any xxunk and this is a perfectly fine way to keep something running over and over . \n\n xxmaj in response to one of your comments , javascript is not multi - threaded so it does not create multiple threads for timers . xxmaj each timer event that fires just puts an event into the event queue and if no xxup js is running at the time , that event is triggered ( thus calling the callback function ) . xxmaj if xxup js is running at the time , the xxup js engine waits until the currently executing xxup js finishes and then services the next event in the event queue ( thus calling the callback ) . \n▁ xxfld 6 xxunk xxfld 7 https : / / stackoverflow.com / users / xxunk xxfld 8 http : / / stackoverflow.com / questions / xxunk / recursive -</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>it places the image not at the end of the current page , but rather at the end of the entire document . xxmaj is there no way to just say , " this figure goes at the bottom of the first page " ? \n▁ xxfld 3 xxmaj paul xxfld 4 https : / / tex.stackexchange.com / users / xxunk xxfld 5 [ ! b ] probably works if the figure fits xxmaj the ! tells latex to ignore numeric constraints . xxmaj as you did n't supply an example xxmaj i 'm having to guess but maybe your class is inhibiting floats on the first page ( the standard classes only inhibit top floats ) ! would over - rule this . xxmaj also of course make sure that the figure appears early enough in the source . \n▁ xxfld 6 xxmaj david xxmaj carlisle xxfld 7 https</td>
#       <td>places the image not at the end of the current page , but rather at the end of the entire document . xxmaj is there no way to just say , " this figure goes at the bottom of the first page " ? \n▁ xxfld 3 xxmaj paul xxfld 4 https : / / tex.stackexchange.com / users / xxunk xxfld 5 [ ! b ] probably works if the figure fits xxmaj the ! tells latex to ignore numeric constraints . xxmaj as you did n't supply an example xxmaj i 'm having to guess but maybe your class is inhibiting floats on the first page ( the standard classes only inhibit top floats ) ! would over - rule this . xxmaj also of course make sure that the figure appears early enough in the source . \n▁ xxfld 6 xxmaj david xxmaj carlisle xxfld 7 https : / / tex.stackexchange.com / users / 1090 xxfld 8 http : / / tex.stackexchange.com / questions / xxunk / place - a - figure - at - the - beginning - end - of - a - specific - page xxfld 9 xxup technology xxfld 10 tex.stackexchange.com xxbos xxfld 1 xxmaj energy required to break single bond vs double bond vs triple bond of a carbon atom in an organic molecule xxfld 2 xxmaj assuming every other conditions are the same , what would be the comparison of energy required to break single bond , double bond and triple bond of a carbon atom in an organic molecule ? \n▁ xxfld 3 xxmaj organ xxfld 4 https : / / chemistry.stackexchange.com / users / 1857 xxfld 5 365 kj / mol for the single bond , 598 kj / mol for the double bond , and 813 kj / mol</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>xxunk - xxunk , perl = true xxrep 4 ) \n xxunk " ) \n▁ # xxmaj code p f i r c \n▁ # 1 xxup p1f2i235r15c145 1 2 235 15 145 \n▁ # 2 xxup p24f1i12r124c96 24 1 12 124 96 \n\n▁ xxfld 6 xxunk xxfld 7 https : / / stackoverflow.com / users / xxunk xxfld 8 http : / / stackoverflow.com / questions / xxunk / how - to - split - a - string - between - two - character - into - sub - groups - in - r xxfld 9 xxup stackoverflow xxfld 10 stackoverflow.com xxbos xxfld 1 xxmaj adjoint xxmaj functors as xxmaj initial xxmaj objects of xxmaj some xxmaj category xxfld 2 xxmaj just as universal arrows can be characterized as initial objects of some appropriate comma category , and ( xxunk can be characterized as ( initial ) terminal objects</td>
#       <td>- xxunk , perl = true xxrep 4 ) \n xxunk " ) \n▁ # xxmaj code p f i r c \n▁ # 1 xxup p1f2i235r15c145 1 2 235 15 145 \n▁ # 2 xxup p24f1i12r124c96 24 1 12 124 96 \n\n▁ xxfld 6 xxunk xxfld 7 https : / / stackoverflow.com / users / xxunk xxfld 8 http : / / stackoverflow.com / questions / xxunk / how - to - split - a - string - between - two - character - into - sub - groups - in - r xxfld 9 xxup stackoverflow xxfld 10 stackoverflow.com xxbos xxfld 1 xxmaj adjoint xxmaj functors as xxmaj initial xxmaj objects of xxmaj some xxmaj category xxfld 2 xxmaj just as universal arrows can be characterized as initial objects of some appropriate comma category , and ( xxunk can be characterized as ( initial ) terminal objects of the appropriate ( xxunk category , is there some ( and if so , what is the ) appropriate category for which , given a functor with a left / right adjoint , we can characterize said adjoint as its initial / terminal object ? xxmaj my goal in this is to characterize [ initial objects , xxunk , limits , xxunk ] all as examples of each other . \n▁ xxfld 3 xxmaj dmitry v xxfld 4 https : / / mathoverflow.net / users / xxunk xxfld 5 xxmaj well , yes : the left adjoint of a functor $ g : c \ to xxup d$ is the initial object in the category whose objects are pairs $ ( h : d \ to xxup c , \ eta : xxunk \ to g xxup h)$ where $ \ eta$ is a natural transformation , and whose morphisms</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>do n't recall which installer type does this , and it 's not xxunk implemented anyway , but the basic idea can work well i think . \n▁ xxfld 6 xxunk xxfld 7 https : / / ux.stackexchange.com / users / xxunk xxfld 8 http : / / ux.stackexchange.com / questions / 64138 / how - to - select - menu - items - that - also - link - to - deeper - items xxfld 9 xxup technology xxfld 10 ux.stackexchange.com xxbos xxfld 1 async &amp; await - poll for alternatives xxfld 2 xxmaj now that we know what is in store for c # 5 , there is apparently still an opening for us to influence the choice of the two new keywords for ' asynchrony ' that were announced by xxmaj anders xxmaj heijsberg yesterday at xxup pdc10 . \n\n async void archivedocuments(list &lt; url &gt; urls</td>
#       <td>n't recall which installer type does this , and it 's not xxunk implemented anyway , but the basic idea can work well i think . \n▁ xxfld 6 xxunk xxfld 7 https : / / ux.stackexchange.com / users / xxunk xxfld 8 http : / / ux.stackexchange.com / questions / 64138 / how - to - select - menu

# %%
config = awd_lstm_lm_config.copy()
config.update({'input_p': 0.6, 'output_p': 0.4, 'weight_p': 0.5, 'embed_p': 0.1, 'hidden_p': 0.2})
model = get_language_model(AWD_LSTM, len(vocab), config=config)

# %%
opt_func = partial(Adam, wd=0.1, eps=1e-7)
cb_funcs = [partial(MixedPrecision, clip=0.1), partial(RNNTrainer, alpha=2, beta=1)]

# %%
learn = Learner(dbch, model, loss_func=CrossEntropyLossFlat(), opt_func=opt_func, cb_funcs=cb_funcs, metrics=[accuracy, Perplexity()])

# %%
learn = language_model_learner(dbch, AWD_LSTM, metrics=[accuracy, Perplexity()], path=data_path, opt_func = partial(Adam, wd=0.1)).to_fp16()

# %%
learn.freeze()
learn.fit_one_cycle(1, 1e-2, moms=(0.8,0.7,0.8))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.000000</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-34-2dbdc5a6fce9> in <module>
#       1 learn.freeze()
# ----> 2 learn.fit_one_cycle(1, 1e-2, moms=(0.8,0.7,0.8))
#
# ~/projetos/fastai2/fastai2/callback/schedule.py in fit_one_cycle(self, n_epoch, lr_max, div, div_final, pct_start, wd, moms, cbs, reset_opt)
#      88     scheds = {'lr': combined_cos(pct_start, lr_max/div, lr_max, lr_max/div_final),
#      89               'mom': combined_cos(pct_start, *moms)}
# ---> 90     self.fit(n_epoch, cbs=ParamScheduler(scheds)+L(cbs), reset_opt=reset_opt, wd=wd)
#      91
#      92 # Cell
#
# ~/projetos/fastai2/fastai2/learner.py in fit(self, n_epoch, lr, wd, cbs, reset_opt)
#     286                     try:
#     287                         self.epoch=epoch;          self('begin_epoch')
# --> 288                         self._do_epoch_train()
#     289                         self._do_epoch_validate()
#     290                     except CancelEpochException:   self('after_cancel_epoch')
#
# ~/projetos/fastai2/fastai2/learner.py in _do_epoch_train(self)
#     261         try:
#     262             self.dl = self.dbunch.train_dl;                  self('begin_train')
# --> 263             self.all_batches()
#     264         except CancelTrainException:                         self('after_cancel_train')
#     265         finally:                                             self('after_train')
#
# ~/projetos/fastai2/fastai2/learner.py in all_batches(self)
#     239     def all_batches(self):
#     240         self.n_iter = len(self.dl)
# --> 241         for o in enumerate(self.dl): self.one_batch(*o)
#     242
#     243     def one_batch(self, i, b):
#
# ~/projetos/fastai2/fastai2/learner.py in one_batch(self, i, b)
#     245         try:
#     246             self._split(b);                                  self('begin_batch')
# --> 247             self.pred = self.model(*self.xb);                self('after_pred')
#     248             if len(self.yb) == 0: return
#     249             self.loss = self.loss_func(self.pred, *self.yb); self('after_loss')
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/projetos/fastai2/fastai2/text/models/awdlstm.py in forward(self, inp, from_embeds)
#     102         if self.packed: inp,lens = self._pack_sequence(inp, sl)
#     103
# --> 104         raw_output = self.input_dp(inp if from_embeds else self.encoder_dp(inp))
#     105         new_hidden,raw_outputs,outputs = [],[],[]
#     106         for l, (rnn,hid_dp) in enumerate(zip(self.rnns, self.hidden_dps)):
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/projetos/fastai2/fastai2/text/models/awdlstm.py in forward(self, words, scale)
#      67         if self.training and self.embed_p != 0:
#      68             size = (self.emb.weight.size(0),1)
# ---> 69             mask = dropout_mask(self.emb.weight.data, size, self.embed_p)
#      70             masked_embed = self.emb.weight * mask
#      71         else: masked_embed = self.emb.weight
#
# ~/projetos/fastai2/fastai2/text/models/awdlstm.py in dropout_mask(x, sz, p)
#      12 def dropout_mask(x, sz, p):
#      13     "Return a dropout mask of the same type as `x`, size `sz`, with probability `p` to cancel an element."
# ---> 14     return x.new(*sz).bernoulli_(1-p).div_(1-p)
#      15
#      16 # Cell
#
# RuntimeError: "bernoulli_scalar_cpu_" not implemented for 'Half'

# %%
learn.unfreeze()
learn.fit_one_cycle(4, 1e-2, moms=(0.8,0.7,0.8))

# %%
learn.show_results()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>input</th>
#       <th>target</th>
#       <th>pred</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>xxbos xxfld 1 xxmaj is it possible to withdraw xxup usd from atms in xxmaj tanzania ? xxfld 2 i will be xxmaj in the following xxmaj xxunk towns , xxmaj arusha , xxmaj xxunk es xxmaj xxunk and xxmaj stone xxmaj town and would like to know where i am best to xxunk xxmaj my stock of xxup usd ? \n\n xxmaj is it possible to withdraw xxup usd from atms in xxmaj tanzania or will i need to withdraw local currency and use a currency exchange ? \n▁ xxfld 3 xxmaj stuart xxfld 4 https : / / travel.stackexchange.com / users / 449 xxfld 5 i have n't been to xxmaj arusha like xxunk , but i have been to quite a few places in xxmaj tanzania and have yet to find an xxup atm in the country that gives out xxup usd . xxmaj so , do n't count on it , though there might be one or two xxunk away somewhere . \n▁ xxfld 6 xxunk xxfld 7 https : / / travel.stackexchange.com / users / xxunk xxfld 8 http : / / travel.stackexchange.com / questions / xxrep 3 9 6 / is - it - possible - to - withdraw - usd - from - atms - in - tanzania / xxunk xxfld 9 xxup culture xxfld 10 travel.stackexchange.com xxbos xxfld 1 xxmaj should i include high school details in xxmaj grad xxmaj school xxmaj resume ? xxfld 2 i was wondering if i should include my high school details in the resume of my graduate school application ? xxmaj it 's unclear about this bit since we are not actually submitting any proof of high school records during grad school application ( they only ask for undergraduate details ) . \n xxmaj but my</td>
#       <td>xxfld 1 xxmaj is it possible to withdraw xxup usd from atms in xxmaj tanzania ? xxfld 2 i will be xxmaj in the following xxmaj xxunk towns , xxmaj arusha , xxmaj xxunk es xxmaj xxunk and xxmaj stone xxmaj town and would like to know where i am best to xxunk xxmaj my stock of xxup usd ? \n\n xxmaj is it possible to withdraw xxup usd from atms in xxmaj tanzania or will i need to withdraw local currency and use a currency exchange ? \n▁ xxfld 3 xxmaj stuart xxfld 4 https : / / travel.stackexchange.com / users / 449 xxfld 5 i have n't been to xxmaj arusha like xxunk , but i have been to quite a few places in xxmaj tanzania and have yet to find an xxup atm in the country that gives out xxup usd . xxmaj so , do n't count on it , though there might be one or two xxunk away somewhere . \n▁ xxfld 6 xxunk xxfld 7 https : / / travel.stackexchange.com / users / xxunk xxfld 8 http : / / travel.stackexchange.com / questions / xxrep 3 9 6 / is - it - possible - to - withdraw - usd - from - atms - in - tanzania / xxunk xxfld 9 xxup culture xxfld 10 travel.stackexchange.com xxbos xxfld 1 xxmaj should i include high school details in xxmaj grad xxmaj school xxmaj resume ? xxfld 2 i was wondering if i should include my high school details in the resume of my graduate school application ? xxmaj it 's unclear about this bit since we are not actually submitting any proof of high school records during grad school application ( they only ask for undergraduate details ) . \n xxmaj but my high</td>
#       <td>xxfld 1 xxmaj how there possible to set xxup usd from a in xxmaj tanzania ? xxfld 2 xxmaj am be living in xxmaj xxup xxmaj tanzania xxmaj , xxmaj tanzania , xxmaj xxunk , xxmaj xxunk , xxmaj xxunk xxmaj town . xxmaj like to be if to am going to live the xxunk money of xxmaj usd . \n\n xxmaj is there possible to get xxup usd from a in xxmaj tanzania ? should i be to return money currency from back xxup local exchange ? \n▁ xxfld 3 xxmaj xxunk xxfld 4 https : / / travel.stackexchange.com / users / xxunk xxfld 5 xxmaj think no seen able xxmaj tanzania , xxmaj . but i have been told xxmaj a few places in xxmaj tanzania . have been to find a online usd in xxmaj xxup of is you the usd . \n\n it i i n't you as the . but . are be a or two of in from . \n▁ xxfld 6 xxmaj xxfld 7 https : / / travel.stackexchange.com / users / xxunk xxfld 8 http : / / travel.stackexchange.com / questions / xxunk 3 3 xxunk / how - it - possible - to - withdraw - usd - from - tanzania - in - tanzania xxfld xxunk xxfld 9 xxup culture xxfld 10 travel.stackexchange.com xxbos xxfld 1 xxmaj how i use a school details in xxmaj grad xxmaj school xxmaj profile ? xxfld 2 xxmaj am wondering if there could be high high school details in my xxmaj of my graduate school application ? xxmaj if seems a whether this , of i are currently asking studying any funding of high school details . my school . . i.e. are have for a details ) . \n\n xxmaj what i question</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>a few questions for you : \n\n\n xxmaj what model router do you have ? \n xxmaj and have you turned on xxup dhcp services on any computers on your network ? \n xxmaj how many computers do you have on your network ? xxmaj can you turn them all off and turn them on 1 at a time until the problem shows up ? \n\n▁ xxfld 6 xxunk xxfld 7 https : / / superuser.com / users / xxunk xxfld 8 http : / / superuser.com / questions / 810510 xxfld 9 xxup technology xxfld 10 superuser.com xxbos xxfld 1 xxmaj why would you use the _ _ line _ _ macro in xxup c++ xxfld 2 i am trying to figure out how people use the _ _ line _ _ macro at work . xxmaj how do you guys use it ? \n▁ xxfld 3 xxmaj scott j xxfld 4 https : / / stackoverflow.com / users / xxunk xxfld 5 xxmaj most of the answers so far have involved some sort of debugging code . xxmaj another use of _ _ line _ _ ( and possibly _ _ file _ _ ) is to enable a macro to generate a unique identifier each time it 's called . xxmaj this implementation of xxunk in c uses these macros to generate labels for a case statement , so it can jump to the last line you called yield from . \n▁ xxfld 6 xxmaj josh xxmaj lee xxfld 7 https : / / stackoverflow.com / users / xxunk xxfld 8 http : / / stackoverflow.com / questions / xxunk / why - would - you - use - the - line - macro - in - c xxfld 9 xxup stackoverflow xxfld 10 stackoverflow.com xxbos xxfld</td>
#       <td>few questions for you : \n\n\n xxmaj what model router do you have ? \n xxmaj and have you turned on xxup dhcp services on any computers on your network ? \n xxmaj how many computers do you have on your network ? xxmaj can you turn them all off and turn them on 1 at a time until the problem shows up ? \n\n▁ xxfld 6 xxunk xxfld 7 https : / / superuser.com / users / xxunk xxfld 8 http : / / superuser.com / questions / 810510 xxfld 9 xxup technology xxfld 10 superuser.com xxbos xxfld 1 xxmaj why would you use the _ _ line _ _ macro in xxup c++ xxfld 2 i am trying to figure out how people use the _ _ line _ _ macro at work . xxmaj how do you guys use it ? \n▁ xxfld 3 xxmaj scott j xxfld 4 https : / / stackoverflow.com / users / xxunk xxfld 5 xxmaj most of the answers so far have involved some sort of debugging code . xxmaj another use of _ _ line _ _ ( and possibly _ _ file _ _ ) is to enable a macro to generate a unique identifier each time it 's called . xxmaj this implementation of xxunk in c uses these macros to generate labels for a case statement , so it can jump to the last line you called yield from . \n▁ xxfld 6 xxmaj josh xxmaj lee xxfld 7 https : / / stackoverflow.com / users / xxunk xxfld 8 http : / / stackoverflow.com / questions / xxunk / why - would - you - use - the - line - macro - in - c xxfld 9 xxup stackoverflow xxfld 10 stackoverflow.com xxbos xxfld 1</td>
#       <td>xxmaj hundred about me . \n\n\n xxmaj how is are is you use to xxmaj xxmaj what what you been off the xxunk and ? the specific ? the network ? \n xxmaj what do people are you use to a network ? \n what you tell them on on ? then them off ? xxrep the time ? you end is up ? \n xxfld 3 xxmaj xxfld 7 https : / / serverfault.com / users / xxunk xxfld 8 http : / / superuser.com / questions / xxunk xxfld 9 xxup technology xxfld 10 superuser.com xxbos xxfld

# %%
learn.save_encoder('enc1')

# %%
from nbdev.export import notebook2script
notebook2script()
# Out:
# Converted 00_core.ipynb.
# Converted index.ipynb.
