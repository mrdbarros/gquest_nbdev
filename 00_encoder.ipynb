# %%
# %load_ext autoreload
# %autoreload 2

# %%
# default_exp encoder

# %% [markdown]
# # Imports
#
# > API details.

# %%
#hide
from nbdev.showdoc import *
from fastcore.test import *

# %%
#export
import pandas as pd # package for high-performance, easy-to-use data structures and data analysis

import re

import string

from fastai2.basics import *
from fastai2.text.all import *
from fastai2.callback.all import *

# %%
#export
import os
if os.path.basename(os.path.normpath(os.getcwd())) == "projetos":
    os.chdir(Path(os.getcwd())/"gquest_nbdev")
print(os.listdir("../data/gquest_data/"))
data_path = Path("../data/gquest_data/")
# Out:
# ['sample_submission.csv', 'test', 'models', 'train']

# %%
import pdb

# %% [markdown]
# # Reading data

# %%
#export
print('Reading data...')

train_data = pd.read_csv(data_path/'train/train.csv')
test_data = pd.read_csv(data_path/'test/test.csv')
sample_submission = pd.read_csv(str(data_path/'sample_submission.csv'))
print('Reading data completed')
# Out:
# Reading data...
# Reading data completed

# %%
#export
print('Size of train_data', train_data.shape)
print('Size of test_data', test_data.shape)
print('Size of sample_submission', sample_submission.shape)
test_eq(train_data.shape,(6079,41))
test_eq(test_data.shape,(476,11))
test_eq(sample_submission.shape,(476,31))
# Out:
# Size of train_data (6079, 41)
# Size of test_data (476, 11)
# Size of sample_submission (476, 31)

# %%
train_data.head()
# Out:
#    qa_id  \
# 0      0
# 1      1
# 2      2
# 3      3
# 4      5
#
#                                                                                                  question_title  \
# 0                                          What am I losing when using extension tubes instead of a macro lens?
# 1  What is the distinction between a city and a sprawl/metroplex... between downtown and a commercial district?
# 2                                                      Maximum protusion length for through-hole component pins
# 3                                                                         Can an affidavit be used in Beit Din?
# 4                                                                  How do you make a binary image in Photoshop?
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              question_body  \
# 0  After playing around with macro photography on-the-cheap (read: reversed lens, rev. lens mounted on a straight lens, passive extension tubes), I would like to get further with this. The problems with the techniques I used is that focus is manual and aperture control is problematic at best. This limited my setup to still subjects (read: dead insects) Now, as spring is approaching, I want to be able to shoot live insects. I believe that for this, autofocus and settable aperture will be of great help.\n\nSo, one obvious but expensive option is a macro lens (say, EF 100mm Macro) However, I am ...
# 1  I am trying to understand what kinds of places the spam values on p 231 refer to in the 5th Edition main book for Shadowrun.\n\nPer p 15, a sprawl is a plex, a plex is a "metropolitan complex, short for metroplex". Per Google a metroplex is " a very large metropolitan area, especially one that is an aggregation of two or more cities".  A city downtown and sprawl downtown would tend to have similar densities, but for some reason the sprawl (which includes suburbs?) has a higher spam zone noise rating (p 231).  Similarly, I'd think of a downtown as being more dense and noisy (e.g. Office bui...
# 2  I'm working on a PCB that has through-hole components on both sides of the board. The "top" side of the board is mounted flush to a Delrin plastic block (the only top-side component is a gas sensor that is fed air samples through hose fittings in the plastic block).\n\nThe flush mounting means that I have to add grooves to the plastic block to accommodate the soldered pins of the bottom-side components. Assuming a standard 0.062" thickness FR4 board, how deep do I need to make the grooves in the plastic block? The only thing I could find is this NASA workmanship standard that states 0.5mm ...
# 3                                                                                                                                                                           An affidavit, from what i understand, is basically a signed document given by a witness to be used as evidence in a trial, without the witness themselves needing to take a stand.\n\nCan an affidavit be used in Beit Din? Or must witnesses take the stand in person for their testimony to count?\n\n(In case i'm misunderstanding what exactly an affidavit is, simply treat it as a signed document by a witness with their testimony.)\n
# 4                                                                                                                                                                                    I am trying to make a binary image. I want more than just the look of the image to be black/white, but I want the actual file to be a binary file. Every pixel should be either black, or white. \n\nI don't just want a monochrome image. I can't have varying shades of gray, every pixel needs to be black or white.\n\nIs this possible? I looked under Image > Mode but nothing there seems to indiciate a binary style image.\n
#
#   question_user_name                                   question_user_page  \
# 0               ysap           https://photo.stackexchange.com/users/1024
# 1      russellpierce             https://rpg.stackexchange.com/users/8774
# 2          Joe Baker    https://electronics.stackexchange.com/users/10157
# 3         Scimonster         https://judaism.stackexchange.com/users/5151
# 4            leigero  https://graphicdesign.stackexchange.com/users/21313
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     answer  \
# 0  I just got extension tubes, so here's the skinny.\n\n\n  ...what am I losing when using tubes...?\n\n\nA very considerable amount of light!  Increasing that distance from the end of the lens to the sensor can cut your light several stops.  Combined with the fact that you'll usually shoot stopped down - expect to need to increase your ISO considerably.\n\nThe fact the macro's are usually considered very very sharp, although I believe that 70-200mm 2.8 is supposed to be quite sharp.\n\nThe ultra low distortion typical of many macros.\n\nI wouldn't worry too much about the bokeh since the DOF...
# 1                                                                                                                                                 It might be helpful to look into the definition of spam zone:\n\n(p.216) spam zone: An area flooded with invasive and/or viral AR advertising, causing noise.\n\nBecause a metroplex has so many marketing targets, it seems a safe assumption that marketers would drown the plex with spam. Spam from the less dense areas would bleed into the urban cores. A smaller city with less urban/suburban territory surrounding it ostensibly wouldn't have as much spam.\n
# 2  Do you even need grooves?  We make several products using through-hole components that are intended to mount using VHB double-sided foam tape.  The boards are 0.062" thick double-sided with PTH and we use a table-top vertical belt sander to bring the component leads almost flush with the solder mask.  In other words, the solder mask isn't touched by the sand paper but the leads are all sanded flat and sitting just proud of the solder mask.\n\nThis works well for small boards.\n\nFor what it's worth, there are commercial machines available that use a rotary saw blade to do the same thing.  ...
# 3  Sending an "affidavit" it is a dispute between Rashi and Rabbeinu Tam.\n\nDevarim 19:15:\n\n\n  לא יקום עד אחד באיש לכל עון ולכל חטאת בכל חטא אשר יחטא על פי שני עדים או על פי שלשה עדים יקום דבר\n\n\nRashi:\n\n\n  ולא שיכתבו עדותם באגרת וישלחו לבית דין\n  \n  And not that they write their testimony in a letter and send it to Beis Din\n\n\nTosefos Bava Basra 40a (continued from 39b):\n\n\n  ועוד אומר ר"י ששמע מן ר"ת שנוהגים לשלח העדים עדותם באיגרת לב"ד וחשיב עדות והא דדרשינן בספרי. מפיהם ולא מפי כתבם לא אתא אלא למעוטי דוקא אלם שאינו בר הגדה אבל ראוי להגדה אין הגדה מעכבת בו \n  \n  R"i said t...
# 4                                                                                                                                                                                                                                                                                                                                                                               Check out Image Trace in Adobe Illustrator. \n\nI like using python and PIL, however.\n\nfrom PIL import Image\nimage_file = Image.open("myimage.bmp") \nimage_file = image_file.convert('1') # convert\nimage_file.save('result.bmp')\n\n
#
#   answer_user_name                                     answer_user_page  \
# 0           rfusca           https://photo.stackexchange.com/users/1917
# 1     Erik Schmidt             https://rpg.stackexchange.com/users/1871
# 2      Dwayne Reid    https://electronics.stackexchange.com/users/64754
# 3    Y     e     z         https://judaism.stackexchange.com/users/4794
# 4             q2ra  https://graphicdesign.stackexchange.com/users/27160
#
#                                                                                                                           url  \
# 0           http://photo.stackexchange.com/questions/9169/what-am-i-losing-when-using-extension-tubes-instead-of-a-macro-lens
# 1  http://rpg.stackexchange.com/questions/47820/what-is-the-distinction-between-a-city-and-a-sprawl-metroplex-between-downtow
# 2              http://electronics.stackexchange.com/questions/154225/maximum-protusion-length-for-through-hole-component-pins
# 3                                       http://judaism.stackexchange.com/questions/55182/can-an-affidavit-be-used-in-beit-din
# 4                          http://graphicdesign.stackexchange.com/questions/35791/how-do-you-make-a-binary-image-in-photoshop
#
#     category  ... question_well_written  answer_helpful  \
# 0  LIFE_ARTS  ...              1.000000        1.000000
# 1    CULTURE  ...              0.888889        0.888889
# 2    SCIENCE  ...              0.777778        0.777778
# 3    CULTURE  ...              0.888889        0.833333
# 4  LIFE_ARTS  ...              1.000000        1.000000
#
#    answer_level_of_information  answer_plausible  answer_relevance  \
# 0                     0.666667          1.000000          1.000000
# 1                     0.555556          0.888889          0.888889
# 2                     0.555556          1.000000          1.000000
# 3                     0.333333          0.833333          1.000000
# 4                     0.666667          1.000000          1.000000
#
#    answer_satisfaction  answer_type_instructions  answer_type_procedure  \
# 0             0.800000                       1.0               0.000000
# 1             0.666667                       0.0               0.000000
# 2             0.666667                       0.0               0.333333
# 3             0.800000                       0.0               0.000000
# 4             0.800000                       1.0               0.000000
#
#    answer_type_reason_explanation  answer_well_written
# 0                        0.000000             1.000000
# 1                        0.666667             0.888889
# 2                        1.000000             0.888889
# 3                        1.000000             1.000000
# 4                        1.000000             1.000000
#
# [5 rows x 41 columns]

# %%
train_data.columns
# Out:
# Index(['qa_id', 'question_title', 'question_body', 'question_user_name',
#        'question_user_page', 'answer', 'answer_user_name', 'answer_user_page',
#        'url', 'category', 'host', 'question_asker_intent_understanding',
#        'question_body_critical', 'question_conversational',
#        'question_expect_short_answer', 'question_fact_seeking',
#        'question_has_commonly_accepted_answer',
#        'question_interestingness_others', 'question_interestingness_self',
#        'question_multi_intent', 'question_not_really_a_question',
#        'question_opinion_seeking', 'question_type_choice',
#        'question_type_compare', 'question_type_consequence',
#        'question_type_definition', 'question_type_entity',
#        'question_type_instructions', 'question_type_procedure',
#        'question_type_reason_explanation', 'question_type_spelling',
#        'question_well_written', 'answer_helpful',
#        'answer_level_of_information', 'answer_plausible', 'answer_relevance',
#        'answer_satisfaction', 'answer_type_instructions',
#        'answer_type_procedure', 'answer_type_reason_explanation',
#        'answer_well_written'],
#       dtype='object')

# %%
sample_submission.columns
# Out:
# Index(['qa_id', 'question_asker_intent_understanding',
#        'question_body_critical', 'question_conversational',
#        'question_expect_short_answer', 'question_fact_seeking',
#        'question_has_commonly_accepted_answer',
#        'question_interestingness_others', 'question_interestingness_self',
#        'question_multi_intent', 'question_not_really_a_question',
#        'question_opinion_seeking', 'question_type_choice',
#        'question_type_compare', 'question_type_consequence',
#        'question_type_definition', 'question_type_entity',
#        'question_type_instructions', 'question_type_procedure',
#        'question_type_reason_explanation', 'question_type_spelling',
#        'question_well_written', 'answer_helpful',
#        'answer_level_of_information', 'answer_plausible', 'answer_relevance',
#        'answer_satisfaction', 'answer_type_instructions',
#        'answer_type_procedure', 'answer_type_reason_explanation',
#        'answer_well_written'],
#       dtype='object')

# %%
targets = list(sample_submission.columns[1:])
targets
# Out:
# ['question_asker_intent_understanding',
#  'question_body_critical',
#  'question_conversational',
#  'question_expect_short_answer',
#  'question_fact_seeking',
#  'question_has_commonly_accepted_answer',
#  'question_interestingness_others',
#  'question_interestingness_self',
#  'question_multi_intent',
#  'question_not_really_a_question',
#  'question_opinion_seeking',
#  'question_type_choice',
#  'question_type_compare',
#  'question_type_consequence',
#  'question_type_definition',
#  'question_type_entity',
#  'question_type_instructions',
#  'question_type_procedure',
#  'question_type_reason_explanation',
#  'question_type_spelling',
#  'question_well_written',
#  'answer_helpful',
#  'answer_level_of_information',
#  'answer_plausible',
#  'answer_relevance',
#  'answer_satisfaction',
#  'answer_type_instructions',
#  'answer_type_procedure',
#  'answer_type_reason_explanation',
#  'answer_well_written']

# %%
text_columns=['question_title', 'question_body', 'question_user_name',
       'question_user_page', 'answer', 'answer_user_name', 'answer_user_page',
       'url', 'category', 'host']

# %%
train_data[targets].describe()
# Out:
#        question_asker_intent_understanding  question_body_critical  \
# count                          6079.000000             6079.000000
# mean                              0.892663                0.595301
# std                               0.132047                0.219470
# min                               0.333333                0.333333
# 25%                               0.777778                0.444444
# 50%                               0.888889                0.555556
# 75%                               1.000000                0.777778
# max                               1.000000                1.000000
#
#        question_conversational  question_expect_short_answer  \
# count              6079.000000                   6079.000000
# mean                  0.057301                      0.698525
# std                   0.182196                      0.350938
# min                   0.000000                      0.000000
# 25%                   0.000000                      0.500000
# 50%                   0.000000                      0.666667
# 75%                   0.000000                      1.000000
# max                   1.000000                      1.000000
#
#        question_fact_seeking  question_has_commonly_accepted_answer  \
# count            6079.000000                            6079.000000
# mean                0.772633                               0.793689
# std                 0.303023                               0.336622
# min                 0.000000                               0.000000
# 25%                 0.666667                               0.666667
# 50%                 1.000000                               1.000000
# 75%                 1.000000                               1.000000
# max                 1.000000                               1.000000
#
#        question_interestingness_others  question_interestingness_self  \
# count                      6079.000000                    6079.000000
# mean                          0.587478                       0.507275
# std                           0.135900                       0.185987
# min                           0.333333                       0.333333
# 25%                           0.444444                       0.333333
# 50%                           0.555556                       0.444444
# 75%                           0.666667                       0.666667
# max                           1.000000                       1.000000
#
#        question_multi_intent  question_not_really_a_question  ...  \
# count            6079.000000                     6079.000000  ...
# mean                0.238745                        0.004469  ...
# std                 0.335057                        0.045782  ...
# min                 0.000000                        0.000000  ...
# 25%                 0.000000                        0.000000  ...
# 50%                 0.000000                        0.000000  ...
# 75%                 0.333333                        0.000000  ...
# max                 1.000000                        1.000000  ...
#
#        question_well_written  answer_helpful  answer_level_of_information  \
# count            6079.000000     6079.000000                  6079.000000
# mean                0.799931        0.925408                     0.654823
# std                 0.178420        0.114836                     0.107666
# min                 0.333333        0.333333                     0.333333
# 25%                 0.666667        0.888889                     0.666667
# 50%                 0.833333        1.000000                     0.666667
# 75%                 1.000000        1.000000                     0.666667
# max                 1.000000        1.000000                     1.000000
#
#        answer_plausible  answer_relevance  answer_satisfaction  \
# count       6079.000000       6079.000000          6079.000000
# mean           0.960054          0.968626             0.854680
# std            0.086926          0.074631             0.130743
# min            0.333333          0.333333             0.200000
# 25%            1.000000          1.000000             0.800000
# 50%            1.000000          1.000000             0.866667
# 75%            1.000000          1.000000             0.933333
# max            1.000000          1.000000             1.000000
#
#        answer_type_instructions  answer_type_procedure  \
# count               6079.000000            6079.000000
# mean                   0.479547               0.130641
# std                    0.422921               0.225718
# min                    0.000000               0.000000
# 25%                    0.000000               0.000000
# 50%                    0.500000               0.000000
# 75%                    1.000000               0.333333
# max                    1.000000               1.000000
#
#        answer_type_reason_explanation  answer_well_written
# count                     6079.000000          6079.000000
# mean                         0.502468             0.908254
# std                          0.407097             0.100708
# min                          0.000000             0.333333
# 25%                          0.000000             0.888889
# 50%                          0.500000             0.888889
# 75%                          1.000000             1.000000
# max                          1.000000             1.000000
#
# [8 rows x 30 columns]

# %%
train_data['question_body'][0]
# Out:
# 'After playing around with macro photography on-the-cheap (read: reversed lens, rev. lens mounted on a straight lens, passive extension tubes), I would like to get further with this. The problems with the techniques I used is that focus is manual and aperture control is problematic at best. This limited my setup to still subjects (read: dead insects) Now, as spring is approaching, I want to be able to shoot live insects. I believe that for this, autofocus and settable aperture will be of great help.\n\nSo, one obvious but expensive option is a macro lens (say, EF 100mm Macro) However, I am not really interested in yet another prime lens. An alternative is the electrical extension tubes.\n\nExcept for maximum focusing distance, what am I losing when using tubes (coupled with a fine lens, say EF70-200/2.8) instead of a macro lens?\n'

# %%
text_columns
# Out:
# ['question_title',
#  'question_body',
#  'question_user_name',
#  'question_user_page',
#  'answer',
#  'answer_user_name',
#  'answer_user_page',
#  'url',
#  'category',
#  'host']

# %%
df_tokenized,token_count=tokenize_df(train_data,text_columns)

# %%
df_tokenized.head()
# Out:
#    qa_id  question_asker_intent_understanding  question_body_critical  \
# 0      0                             1.000000                0.333333
# 1      1                             1.000000                1.000000
# 2      2                             0.888889                0.666667
# 3      3                             0.888889                0.666667
# 4      5                             1.000000                0.666667
#
#    question_conversational  question_expect_short_answer  \
# 0                 0.000000                           0.0
# 1                 0.000000                           0.5
# 2                 0.000000                           1.0
# 3                 0.666667                           1.0
# 4                 0.000000                           1.0
#
#    question_fact_seeking  question_has_commonly_accepted_answer  \
# 0                    0.0                                    0.0
# 1                    1.0                                    1.0
# 2                    1.0                                    1.0
# 3                    1.0                                    1.0
# 4                    1.0                                    1.0
#
#    question_interestingness_others  question_interestingness_self  \
# 0                         1.000000                       1.000000
# 1                         0.444444                       0.444444
# 2                         0.666667                       0.444444
# 3                         0.444444                       0.444444
# 4                         0.666667                       0.666667
#
#    question_multi_intent  ...  answer_helpful  answer_level_of_information  \
# 0               0.000000  ...        1.000000                     0.666667
# 1               0.666667  ...        0.888889                     0.555556
# 2               0.333333  ...        0.777778                     0.555556
# 3               0.000000  ...        0.833333                     0.333333
# 4               0.000000  ...        1.000000                     0.666667
#
#    answer_plausible  answer_relevance  answer_satisfaction  \
# 0          1.000000          1.000000             0.800000
# 1          0.888889          0.888889             0.666667
# 2          1.000000          1.000000             0.666667
# 3          0.833333          1.000000             0.800000
# 4          1.000000          1.000000             0.800000
#
#    answer_type_instructions  answer_type_procedure  \
# 0                       1.0               0.000000
# 1                       0.0               0.000000
# 2                       0.0               0.333333
# 3                       0.0               0.000000
# 4                       1.0               0.000000
#
#    answer_type_reason_explanation  answer_well_written  \
# 0                        0.000000             1.000000
# 1                        0.666667             0.888889
# 2                        1.000000             0.888889
# 3                        1.000000             1.000000
# 4                        1.000000             1.000000
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       text
# 0  [xxbos, xxfld, 1, xxmaj, what, am, i, losing, when, using, extension, tubes, instead, of, a, macro, lens, ?, xxfld, 2, xxmaj, after, playing, around, with, macro, photography, on, -, the, -, cheap, (, read, :, reversed, lens, ,, rev, ., lens, mounted, on, a, straight, lens, ,, passive, extension, tubes, ), ,, i, would, like, to, get, further, with, this, ., xxmaj, the, problems, with, the, techniques, i, used, is, that, focus, is, manual, and, aperture, control, is, problematic, at, best, ., xxmaj, this, limited, my, setup, to, still, subjects, (, read, :, dead, insects, ), xxmaj, now, ,, ...
# 1  [xxbos, xxfld, 1, xxmaj, what, is, the, distinction, between, a, city, and, a, sprawl, /, metroplex, …, between, downtown, and, a, commercial, district, ?, xxfld, 2, i, am, trying, to, understand, what, kinds, of, places, the, spam, values, on, p, 231, refer, to, in, the, 5th, xxmaj, edition, main, book, for, xxmaj, shadowrun, ., \n\n, xxmaj, per, p, 15, ,, a, sprawl, is, a, plex, ,, a, plex, is, a, ", metropolitan, complex, ,, short, for, metroplex, ", ., xxmaj, per, xxmaj, google, a, metroplex, is, ", a, very, large, metropolitan, area, ,, especially, one, that, is, an, aggregation, of, ...
# 2  [xxbos, xxfld, 1, xxmaj, maximum, protusion, length, for, through, -, hole, component, pins, xxfld, 2, xxmaj, i, 'm, working, on, a, xxup, pcb, that, has, through, -, hole, components, on, both, sides, of, the, board, ., xxmaj, the, ", top, ", side, of, the, board, is, mounted, flush, to, a, xxmaj, delrin, plastic, block, (, the, only, top, -, side, component, is, a, gas, sensor, that, is, fed, air, samples, through, hose, fittings, in, the, plastic, block, ), ., \n\n, xxmaj, the, flush, mounting, means, that, i, have, to, add, grooves, to, the, plastic, block, to, accommodate, the, solder...
# 3  [xxbos, xxfld, 1, xxmaj, can, an, affidavit, be, used, in, xxmaj, beit, xxmaj, din, ?, xxfld, 2, xxmaj, an, affidavit, ,, from, what, i, understand, ,, is, basically, a, signed, document, given, by, a, witness, to, be, used, as, evidence, in, a, trial, ,, without, the, witness, themselves, needing, to, take, a, stand, ., \n\n, xxmaj, can, an, affidavit, be, used, in, xxmaj, beit, xxmaj, din, ?, xxmaj, or, must, witnesses, take, the, stand, in, person, for, their, testimony, to, count, ?, \n\n, (, in, case, i, 'm, misunderstanding, what, exactly, an, affidavit, is, ,, simply, treat, it, as,...
# 4                                                     [xxbos, xxfld, 1, xxmaj, how, do, you, make, a, binary, image, in, xxmaj, photoshop, ?, xxfld, 2, i, am, trying, to, make, a, binary, image, ., i, want, more, than, just, the, look, of, the, image, to, be, black, /, white, ,, but, i, want, the, actual, file, to, be, a, binary, file, ., xxmaj, every, pixel, should, be, either, black, ,, or, white, ., \n\n, i, do, n't, just, want, a, monochrome, image, ., i, ca, n't, have, varying, shades, of, gray, ,, every, pixel, needs, to, be, black, or, white, ., \n\n, xxmaj, is, this, possible, ?, i, ...]
#
# [5 rows x 32 columns]

# %%
vocab = make_vocab(token_count)
vocab
# Out:
# ['xxunk',
#  'xxpad',
#  'xxbos',
#  'xxeos',
#  'xxfld',
#  'xxrep',
#  'xxwrep',
#  'xxup',
#  'xxmaj',
#  '/',
#  'the',
#  ',',
#  '-',
#  '.',
#  'to',
#  '\n▁',
#  'a',
#  ':',
#  ')',
#  'i',
#  'is',
#  '\n\n',
#  'and',
#  'of',
#  '"',
#  '(',
#  'in',
#  '\n',
#  'it',
#  'that',
#  '\\',
#  'you',
#  '$',
#  'for',
#  ';',
#  'this',
#  '?',
#  '=',
#  'users',
#  'https',
#  '}',
#  "'",
#  'with',
#  'on',
#  'be',
#  '3',
#  '>',
#  '1',
#  'if',
#  'have',
#  'as',
#  'not',
#  'can',
#  'are',
#  '<',
#  '2',
#  '{',
#  'or',
#  'but',
#  'do',
#  '\n\n\n',
#  '4',
#  'http',
#  '5',
#  'from',
#  'my',
#  "'s",
#  "n't",
#  '10',
#  '6',
#  ']',
#  'an',
#  '7',
#  '8',
#  'questions',
#  '9',
#  '\n\n▁',
#  'so',
#  'how',
#  'what',
#  'at',
#  'your',
#  'there',
#  'will',
#  'would',
#  'stackoverflow.com',
#  'by',
#  'use',
#  'one',
#  'when',
#  'which',
#  'like',
#  'all',
#  '0',
#  'some',
#  'does',
#  '&',
#  'get',
#  'any',
#  'using',
#  'they',
#  'then',
#  '[',
#  'was',
#  '*',
#  'just',
#  'more',
#  '+',
#  'should',
#  'has',
#  'we',
#  'other',
#  'want',
#  '#',
#  "'m",
#  'need',
#  'only',
#  'way',
#  'no',
#  'about',
#  'am',
#  'up',
#  'time',
#  'also',
#  'new',
#  'out',
#  'could',
#  'technology',
#  'code',
#  '…',
#  'where',
#  'me',
#  'make',
#  '!',
#  'file',
#  'here',
#  'same',
#  'than',
#  'them',
#  'know',
#  'into',
#  'work',
#  'two',
#  'set',
#  'data',
#  'see',
#  'because',
#  '\n\n\n▁',
#  'first',
#  'why',
#  'question',
#  'after',
#  'used',
#  'example',
#  'now',
#  'these',
#  'find',
#  'their',
#  'function',
#  '%',
#  '_',
#  'problem',
#  'he',
#  "'ve",
#  'x',
#  'something',
#  'good',
#  'even',
#  'user',
#  'page',
#  'very',
#  'each',
#  'may',
#  'different',
#  'been',
#  'server',
#  'think',
#  'right',
#  'return',
#  'such',
#  'c',
#  'much',
#  'class',
#  'most',
#  'between',
#  'another',
#  'value',
#  'its',
#  'stackoverflow',
#  'add',
#  'since',
#  'list',
#  'did',
#  'go',
#  'however',
#  'still',
#  'error',
#  '|',
#  'string',
#  'number',
#  'name',
#  'd',
#  'help',
#  'case',
#  'without',
#  'possible',
#  'create',
#  'had',
#  'well',
#  'end',
#  'system',
#  'while',
#  'might',
#  'before',
#  'many',
#  'public',
#  'line',
#  'try',
#  'change',
#  'following',
#  'etc',
#  'really',
#  'ca',
#  'through',
#  'say',
#  'being',
#  'take',
#  'over',
#  "'re",
#  'answer',
#  'text',
#  'image',
#  '\n\n\n\n',
#  'who',
#  'both',
#  'people',
#  'table',
#  'files',
#  'point',
#  'int',
#  'culture',
#  'were',
#  'b',
#  'run',
#  'type',
#  'back',
#  'better',
#  'else',
#  'trying',
#  'too',
#  'look',
#  'field',
#  'key',
#  'able',
#  'sure',
#  'off',
#  'start',
#  'english.stackexchange.com',
#  'current',
#  'superuser.com',
#  'going',
#  'read',
#  'best',
#  'seems',
#  'electronics.stackexchange.com',
#  'things',
#  'method',
#  'every',
#  'down',
#  'found',
#  'script',
#  'w',
#  'edit',
#  'access',
#  'left',
#  'application',
#  'site',
#  'serverfault.com',
#  'let',
#  'looking',
#  'his',
#  'those',
#  "'d",
#  'part',
#  'android',
#  'science',
#  'size',
#  'update',
#  'long',
#  'y',
#  '--',
#  'object',
#  'output',
#  'working',
#  'works',
#  'array',
#  'true',
#  'select',
#  'running',
#  'lot',
#  'our',
#  'instead',
#  'form',
#  'check',
#  'show',
#  'php',
#  'windows',
#  'actually',
#  'information',
#  "'ll",
#  'app',
#  'math.stackexchange.com',
#  'order',
#  'word',
#  'though',
#  'give',
#  'second',
#  'put',
#  'thanks',
#  'above',
#  'source',
#  'own',
#  'simple',
#  'less',
#  'version',
#  'tried',
#  'around',
#  'solution',
#  'life_arts',
#  'done',
#  'having',
#  'always',
#  's',
#  'bit',
#  'var',
#  'times',
#  'database',
#  'based',
#  'already',
#  'given',
#  'thing',
#  'again',
#  'power',
#  'call',
#  'either',
#  'values',
#  'post',
#  'probably',
#  'doing',
#  'div',
#  'result',
#  'non',
#  'option',
#  'e',
#  'group',
#  'view',
#  'must',
#  'physics.stackexchange.com',
#  'last',
#  'few',
#  'game',
#  'input',
#  '\n▁\n▁',
#  'never',
#  'open',
#  'means',
#  'link',
#  'null',
#  'level',
#  'mean',
#  'specific',
#  'f',
#  'web',
#  'command',
#  'issue',
#  'write',
#  'understand',
#  '..',
#  'note',
#  'single',
#  'n',
#  'high',
#  'top',
#  'small',
#  'correct',
#  'content',
#  'difference',
#  'please',
#  'someone',
#  'idea',
#  'enough',
#  'getting',
#  'next',
#  'p',
#  'anyone',
#  'multiple',
#  'button',
#  'least',
#  'made',
#  'query',
#  'm',
#  'default',
#  'message',
#  'called',
#  'space',
#  'tex.stackexchange.com',
#  'anything',
#  'once',
#  'install',
#  'similar',
#  'below',
#  'got',
#  'far',
#  't',
#  'side',
#  'device',
#  'service',
#  'us',
#  'said',
#  'keep',
#  'network',
#  'project',
#  'reason',
#  'process',
#  'wrong',
#  'test',
#  'google',
#  'simply',
#  'often',
#  'old',
#  'little',
#  'images',
#  'tell',
#  'main',
#  'column',
#  'path',
#  'remove',
#  'kind',
#  'quite',
#  'display',
#  'voltage',
#  'sql',
#  'static',
#  'usually',
#  'course',
#  'hard',
#  'html',
#  'fine',
#  'askubuntu.com',
#  'programmers.stackexchange.com',
#  'custom',
#  'results',
#  'makes',
#  'available',
#  'under',
#  'r',
#  'rpg.stackexchange.com',
#  'void',
#  'state',
#  'place',
#  'per',
#  'points',
#  'created',
#  'url',
#  'large',
#  'real',
#  'false',
#  'local',
#  'bad',
#  'maybe',
#  'via',
#  'print',
#  'book',
#  'machine',
#  'general',
#  'full',
#  'control',
#  'making',
#  'save',
#  'home',
#  'rather',
#  'reference',
#  'water',
#  'e.g.',
#  'standard',
#  'wo',
#  'g',
#  'free',
#  'click',
#  'log',
#  'inside',
#  'original',
#  'player',
#  'computer',
#  'whether',
#  'java',
#  'product',
#  'energy',
#  'words',
#  'color',
#  '100',
#  'gaming.stackexchange.com',
#  'seem',
#  'map',
#  'fact',
#  'search',
#  'common',
#  'allow',
#  'title',
#  'address',
#  'within',
#  'load',
#  'certain',
#  'design',
#  'model',
#  'unix.stackexchange.com',
#  'him',
#  'likely',
#  'options',
#  'program',
#  'drive',
#  'sense',
#  'memory',
#  'email',
#  'three',
#  'date',
#  'mode',
#  'come',
#  'yes',
#  'looks',
#  'apple.stackexchange.com',
#  'person',
#  'particular',
#  'low',
#  'element',
#  'uses',
#  'block',
#  'private',
#  'package',
#  'consider',
#  'javascript',
#  'says',
#  'client',
#  'until',
#  'security',
#  'everything',
#  'academia.stackexchange.com',
#  'changes',
#  'whole',
#  'photo.stackexchange.com',
#  'store',
#  'settings',
#  'easy',
#  'items',
#  'lines',
#  'several',
#  'ubuntu',
#  'years',
#  'include',
#  'pretty',
#  'software',
#  'domain',
#  'yet',
#  'i.e.',
#  'light',
#  'window',
#  'her',
#  'exactly',
#  'world',
#  'drupal.stackexchange.com',
#  'needs',
#  'variable',
#  'she',
#  'related',
#  'required',
#  'move',
#  'connection',
#  '^',
#  'account',
#  'diy.stackexchange.com',
#  'ux.stackexchange.com',
#  'event',
#  'background',
#  'during',
#  'play',
#  'gets',
#  'password',
#  'instance',
#  'important',
#  'scifi.stackexchange.com',
#  'linux',
#  'send',
#  'item',
#  'directory',
#  'objects',
#  'range',
#  'numbers',
#  'sort',
#  'echo',
#  'screen',
#  'clear',
#  'switch',
#  'force',
#  'import',
#  'setting',
#  'card',
#  'day',
#  'nothing',
#  'great',
#  'body',
#  'security.stackexchange.com',
#  'students',
#  'big',
#  'paper',
#  'build',
#  'mail',
#  'circuit',
#  'python',
#  '12',
#  'ask',
#  'character',
#  'index',
#  'short',
#  'term',
#  'against',
#  'adding',
#  'seen',
#  'normal',
#  'style',
#  'filter',
#  'effect',
#  'reading',
#  'itself',
#  'hand',
#  'disk',
#  'god',
#  '“',
#  'close',
#  'thought',
#  '”',
#  'hit',
#  'meaning',
#  'rules',
#  'position',
#  'turn',
#  'language',
#  'problems',
#  'added',
#  'box',
#  'final',
#  'car',
#  'english',
#  'mm',
#  'ell.stackexchange.com',
#  'fields',
#  'currently',
#  'loop',
#  'sometimes',
#  'others',
#  'api',
#  'functions',
#  '`',
#  'support',
#  'format',
#  'due',
#  'comes',
#  'gamedev.stackexchange.com',
#  'white',
#  'length',
#  'document',
#  'takes',
#  'folder',
#  'methods',
#  'job',
#  'basic',
#  'stop',
#  '20',
#  'mathoverflow.net',
#  'figure',
#  'delete',
#  'website',
#  'fix',
#  'dev',
#  'wordpress.stackexchange.com',
#  'menu',
#  'k',
#  'later',
#  'days',
#  'answers',
#  'os',
#  'choose',
#  'head',
#  'attack',
#  'action',
#  'amount',
#  'bottom',
#  'library',
#  'directly',
#  'company',
#  'matter',
#  'copy',
#  'especially',
#  'thus',
#  'needed',
#  'although',
#  'magento.stackexchange.com',
#  'comment',
#  'elements',
#  'gives',
#  'ip',
#  'year',
#  'vector',
#  'mechanics.stackexchange.com',
#  'node',
#  'ok',
#  'area',
#  'creating',
#  'assume',
#  'speed',
#  'bytes',
#  'def',
#  'z',
#  'installed',
#  'pi',
#  'away',
#  'sound',
#  'stack',
#  'provide',
#  'black',
#  'graphicdesign.stackexchange.com',
#  'root',
#  'therefore',
#  'links',
#  'row',
#  'td',
#  'across',
#  'engine',
#  'shows',
#  'pages',
#  'front',
#  'pass',
#  'terms',
#  'approach',
#  'bicycles.stackexchange.com',
#  'money.stackexchange.com',
#  'connected',
#  'zero',
#  'insert',
#  'xml',
#  'cause',
#  'feel',
#  'examples',
#  'property',
#  'goes',
#  'experience',
#  'module',
#  'stuff',
#  'camera',
#  'research',
#  'rest',
#  'rule',
#  'none',
#  'ways',
#  'connect',
#  'apply',
#  'properties',
#  'remember',
#  'section',
#  'useful',
#  'complete',
#  'performance',
#  'money',
#  'mysql',
#  'signal',
#  'completely',
#  'according',
#  'port',
#  'travel.stackexchange.com',
#  'mathematica.stackexchange.com',
#  'cases',
#  'label',
#  'total',
#  'started',
#  '11',
#  'draw',
#  'comments',
#  'basically',
#  'longer',
#  'revision',
#  'context',
#  'known',
#  'replace',
#  'higher',
#  'configuration',
#  'response',
#  'defined',
#  'whatever',
#  'hash',
#  'article',
#  'gis.stackexchange.com',
#  'h',
#  'session',
#  'perhaps',
#  'browser',
#  'guess',
#  'thinking',
#  'changed',
#  'missing',
#  'buy',
#  'count',
#  'manager',
#  'programming',
#  'lens',
#  'actual',
#  'template',
#  'starting',
#  'dba.stackexchange.com',
#  'avoid',
#  'feature',
#  'boardgames.stackexchange.com',
#  'cooking.stackexchange.com',
#  'request',
#  'step',
#  'double',
#  'allows',
#  'damage',
#  'generally',
#  'sudo',
#  'handle',
#  'css',
#  'contains',
#  'red',
#  'setup',
#  'happens',
#  'business',
#  'self',
#  'law',
#  'changing',
#  'games',
#  'otherwise',
#  'extra',
#  'tool',
#  'judaism.stackexchange.com',
#  'unless',
#  'special',
#  're',
#  'parts',
#  '15',
#  'desktop',
#  'theory',
#  'hope',
#  'frame',
#  '30',
#  'existing',
#  'jquery',
#  'online',
#  'playing',
#  'info',
#  'music.stackexchange.com',
#  'solve',
#  'boot',
#  'believe',
#  'statement',
#  'issues',
#  'choice',
#  'outside',
#  'languages',
#  'random',
#  'easier',
#  'room',
#  'books',
#  'cost',
#  'suggest',
#  'plugin',
#  'wondering',
#  'players',
#  'sharepoint.stackexchange.com',
#  'correctly',
#  'v',
#  'selected',
#  'follow',
#  'require',
#  'mind',
#  'bike',
#  'distance',
#  'devices',
#  'present',
#  '50',
#  'easily',
#  'child',
#  'explain',
#  'almost',
#  'rate',
#  'vs',
#  'bin',
#  'further',
#  'writing',
#  'written',
#  'asked',
#  'applications',
#  'depends',
#  'house',
#  'probability',
#  'tree',
#  'define',
#  'live',
#  'couple',
#  'contain',
#  'minutes',
#  'john',
#  'determine',
#  'login',
#  'break',
#  'exception',
#  'ones',
#  'environment',
#  'returns',
#  'meta.stackexchange.com',
#  'tag',
#  'battery',
#  'variables',
#  'separate',
#  'classes',
#  'usr',
#  'price',
#  'location',
#  'phone',
#  'asking',
#  'task',
#  'fixed',
#  'expect',
#  'recently',
#  'happen',
#  'types',
#  'ideas',
#  'base',
#  'along',
#  'structure',
#  'various',
#  'width',
#  'columns',
#  '2013',
#  'life',
#  'thread',
#  'sentence',
#  'previous',
#  'empty',
#  '’s',
#  'limit',
#  'host',
#  'details',
#  'volume',
#  'situation',
#  'assuming',
#  'future',
#  'names',
#  'deal',
#  'download',
#  'series',
#  'wanted',
#  'sites',
#  'usb',
#  'moving',
#  'customer',
#  'depending',
#  'christianity.stackexchange.com',
#  'l',
#  'negative',
#  'specifically',
#  'share',
#  'mark',
#  'layer',
#  'taking',
#  'equivalent',
#  'came',
#  'mac',
#  'including',
#  'li',
#  'considered',
#  'definition',
#  'gb',
#  'match',
#  'mentioned',
#  '200',
#  'additional',
#  'bar',
#  'oil',
#  'necessary',
#  'positive',
#  'automatically',
#  'together',
#  'prevent',
#  'ever',
#  'tools',
#  'earth',
#  'chain',
#  'learn',
#  'algorithm',
#  '24',
#  'keys',
#  ...]

# %%
import pickle
with open(data_path/'vocab.pkl', 'wb') as vocab_file:
 
    pickle.dump(vocab, vocab_file)

# %%
tfm = Numericalize(make_vocab(token_count))

# %%
splits = RandomSplitter()(df_tokenized)

# %%
splits
# Out:
# ((#4864) [4389,3736,4394,5088,2468,3640,2885,1045,1987,3284...],
#  (#1215) [167,5128,3678,5466,2457,3721,2729,797,288,3586...])

# %%
dsrc = DataSource(df_tokenized, [[attrgetter("text"), tfm]], splits=splits, dl_type=LMDataLoader)

# %%
bs,sl = 32,72
dbch = dsrc.databunch(bs=bs, seq_len=sl)

# %%
dbch.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#       <th>text_</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>xxbos xxfld 1 xxmaj implementing a custom formsauthenticationprovider using xxmaj owin , xxmaj katana , and xxmaj nancy xxfld 2 i am working on implementing a custom formsauthenticationprovider and xxmaj i 'm getting a xxunk conversion error . \n\n xxmaj no conversion available between xxunk \n [ xxunk ] and microsoft.owin.owinmiddleware \n xxmaj parameter name : signature \n\n\n xxmaj my stack includes \n\n\n xxmaj owin \n xxmaj katana \n xxmaj nancy \n\n\n</td>
#       <td>xxfld 1 xxmaj implementing a custom formsauthenticationprovider using xxmaj owin , xxmaj katana , and xxmaj nancy xxfld 2 i am working on implementing a custom formsauthenticationprovider and xxmaj i 'm getting a xxunk conversion error . \n\n xxmaj no conversion available between xxunk \n [ xxunk ] and microsoft.owin.owinmiddleware \n xxmaj parameter name : signature \n\n\n xxmaj my stack includes \n\n\n xxmaj owin \n xxmaj katana \n xxmaj nancy \n\n\n xxmaj</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>( xxunk ) ; \n▁ int len = xxunk , xxunk ) , " % y-%m-%d % h:%m:%s " , timeinfo ) ; \n▁ xxunk ! = 0 ) ; \n\n▁ int rv = xxunk , buflen , " % ld = % s ( % s ) " , ( xxunk , xxunk , \n▁ " pacific xxmaj time ( us &amp; &amp; xxmaj canada ) " ) ; \n▁ xxunk</td>
#       <td>xxunk ) ; \n▁ int len = xxunk , xxunk ) , " % y-%m-%d % h:%m:%s " , timeinfo ) ; \n▁ xxunk ! = 0 ) ; \n\n▁ int rv = xxunk , buflen , " % ld = % s ( % s ) " , ( xxunk , xxunk , \n▁ " pacific xxmaj time ( us &amp; &amp; xxmaj canada ) " ) ; \n▁ xxunk &gt;</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>from xxmaj gabriel , he says \n\n\n▁ xxmaj lucifer xxmaj this world is mine , in time . \n\n\n xxmaj so two reasons here : xxmaj he wants to win his bet with xxmaj god , and he wants to stop xxmaj mammon from taking over the world , which he considers to be his . \n▁ xxfld 6 jono xxfld 7 https : / / scifi.stackexchange.com / users / xxunk xxfld</td>
#       <td>xxmaj gabriel , he says \n\n\n▁ xxmaj lucifer xxmaj this world is mine , in time . \n\n\n xxmaj so two reasons here : xxmaj he wants to win his bet with xxmaj god , and he wants to stop xxmaj mammon from taking over the world , which he considers to be his . \n▁ xxfld 6 jono xxfld 7 https : / / scifi.stackexchange.com / users / xxunk xxfld 8</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>have spiked , at least that much . \n\n xxmaj the price per killowatt hour is comperable to last year as well . \n\n xxmaj we generally clock in at around 1200 to 1800 kilowatt hours . xxmaj last month was a bit over 2800 . \n\n xxmaj we already tried ( unsuccessfully ) to lodge a complaint with the electric company . \n\n xxmaj the odd thing is the variance -$150</td>
#       <td>spiked , at least that much . \n\n xxmaj the price per killowatt hour is comperable to last year as well . \n\n xxmaj we generally clock in at around 1200 to 1800 kilowatt hours . xxmaj last month was a bit over 2800 . \n\n xxmaj we already tried ( unsuccessfully ) to lodge a complaint with the electric company . \n\n xxmaj the odd thing is the variance -$150 one</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>the project . \n\n xxmaj lying is certainly a very very bad form of communication . xxmaj your colleague is being extremely unprofessional and so are you . xxmaj you both are doing nothing good to improve the perception of programmers . \n\n i would advise you to go right away to management . xxmaj however , i have gotten in trouble in the past for having been too " honest "</td>
#       <td>project . \n\n xxmaj lying is certainly a very very bad form of communication . xxmaj your colleague is being extremely unprofessional and so are you . xxmaj you both are doing nothing good to improve the perception of programmers . \n\n i would advise you to go right away to management . xxmaj however , i have gotten in trouble in the past for having been too " honest " (</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>new field type and discounts are controlled per product and at definable quantities . \n\n xxmaj does need xxmaj matrix installed though . \n▁ xxfld 6 xxmaj peter xxmaj lewis xxfld 7 https : / / expressionengine.stackexchange.com / users / 425 xxfld 8 http : / / expressionengine.stackexchange.com / questions / xxunk / quantity - based - discount - for - single - product - in - expresso - store xxfld 9</td>
#       <td>field type and discounts are controlled per product and at definable quantities . \n\n xxmaj does need xxmaj matrix installed though . \n▁ xxfld 6 xxmaj peter xxmaj lewis xxfld 7 https : / / expressionengine.stackexchange.com / users / 425 xxfld 8 http : / / expressionengine.stackexchange.com / questions / xxunk / quantity - based - discount - for - single - product - in - expresso - store xxfld 9 xxup</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>full - time , then do a resync from your current iphoto state , by deleting the xxmaj photos xxmaj library &amp; &amp; importing again . \n xxmaj doing that will then erase any work done in xxmaj photos &amp; &amp; replace it with the latest iphoto state \n▁ xxfld 6 xxmaj tetsujin xxfld 7 https : / / apple.stackexchange.com / users / xxunk xxfld 8 http : / / apple.stackexchange.com /</td>
#       <td>- time , then do a resync from your current iphoto state , by deleting the xxmaj photos xxmaj library &amp; &amp; importing again . \n xxmaj doing that will then erase any work done in xxmaj photos &amp; &amp; replace it with the latest iphoto state \n▁ xxfld 6 xxmaj tetsujin xxfld 7 https : / / apple.stackexchange.com / users / xxunk xxfld 8 http : / / apple.stackexchange.com / questions</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>fleshgrinder 's points : \n\n xxmaj use proper xxunk notation for property and method names \n\n xxmaj this is a stylistic choice , though one i agree with . xxmaj this is entirely up to you . \n\n xxmaj keep everything protected unless you have a good reason to keep it private or expose it with public \n\n xxmaj good advice , but to expand upon this , an element only has</td>
#       <td>'s points : \n\n xxmaj use proper xxunk notation for property and method names \n\n xxmaj this is a stylistic choice , though one i agree with . xxmaj this is entirely up to you . \n\n xxmaj keep everything protected unless you have a good reason to keep it private or expose it with public \n\n xxmaj good advice , but to expand upon this , an element only has to</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>\n\n ? &gt; \n▁ / / here is an empty line in the file \n\n▁ xxfld 6 xxmaj fabian xxmaj blechschmidt xxfld 7 https : / / magento.stackexchange.com / users / 217 xxfld 8 http : / / magento.stackexchange.com / questions / xxunk / magento - xxunk - strange - empty - row - at - beginning - of - file xxfld 9 xxup technology xxfld 10 magento.stackexchange.com xxbos xxfld 1 xxmaj</td>
#       <td>? &gt; \n▁ / / here is an empty line in the file \n\n▁ xxfld 6 xxmaj fabian xxmaj blechschmidt xxfld 7 https : / / magento.stackexchange.com / users / 217 xxfld 8 http : / / magento.stackexchange.com / questions / xxunk / magento - xxunk - strange - empty - row - at - beginning - of - file xxfld 9 xxup technology xxfld 10 magento.stackexchange.com xxbos xxfld 1 xxmaj adding</td>
#     </tr>
#   </tbody>
# </table>

# %%
config = awd_lstm_lm_config.copy()
config.update({'input_p': 0.6, 'output_p': 0.4, 'weight_p': 0.5, 'embed_p': 0.1, 'hidden_p': 0.2})
model = get_language_model(AWD_LSTM, len(vocab), config=config)

# %%
opt_func = partial(Adam, wd=0.1, eps=1e-7)
cb_funcs = [partial(MixedPrecision, clip=0.1), partial(RNNTrainer, alpha=2, beta=1)]

# %%
learn = language_model_learner(dbch, AWD_LSTM, metrics=[accuracy, Perplexity()], path=data_path, opt_func = partial(Adam, wd=0.1)).to_fp16()

# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %%
learn.freeze()
learn.fit_one_cycle(1, 1e-2, moms=(0.8,0.7,0.8))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.264124</td>
#       <td>3.845765</td>
#       <td>0.342076</td>
#       <td>46.794464</td>
#       <td>02:02</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.unfreeze()
learn.fit_one_cycle(4, 1e-3, moms=(0.8,0.7,0.8))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.694865</td>
#       <td>3.617721</td>
#       <td>0.374017</td>
#       <td>37.252575</td>
#       <td>02:16</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.497900</td>
#       <td>3.440371</td>
#       <td>0.395653</td>
#       <td>31.198532</td>
#       <td>02:17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.330299</td>
#       <td>3.329404</td>
#       <td>0.411470</td>
#       <td>27.921686</td>
#       <td>02:17</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.180673</td>
#       <td>3.304468</td>
#       <td>0.414857</td>
#       <td>27.234047</td>
#       <td>02:18</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit_one_cycle(4, 1e-5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.222468</td>
#       <td>3.303224</td>
#       <td>0.415022</td>
#       <td>27.200193</td>
#       <td>02:20</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.210910</td>
#       <td>3.301223</td>
#       <td>0.415363</td>
#       <td>27.145826</td>
#       <td>02:19</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.143451</td>
#       <td>3.300037</td>
#       <td>0.415612</td>
#       <td>27.113640</td>
#       <td>02:21</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.206882</td>
#       <td>3.299779</td>
#       <td>0.415646</td>
#       <td>27.106653</td>
#       <td>02:19</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.show_results()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>input</th>
#       <th>target</th>
#       <th>pred</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>xxbos xxfld 1 xxmaj add targeting when posting to a page using xxmaj facebook xxup api xxfld 2 xxmaj i 'm trying to post to a page on facebook using the facebook xxup api . xxmaj but i want to customize the post target . \n\n xxmaj when i post to a page on facebook i get these results : \n\n\n\n xxmaj you get xxmaj shared with : ( languages … )</td>
#       <td>xxfld 1 xxmaj add targeting when posting to a page using xxmaj facebook xxup api xxfld 2 xxmaj i 'm trying to post to a page on facebook using the facebook xxup api . xxmaj but i want to customize the post target . \n\n xxmaj when i post to a page on facebook i get these results : \n\n\n\n xxmaj you get xxmaj shared with : ( languages … ) and</td>
#       <td>xxfld 1 xxmaj how a xxup using to a page xxfld xxmaj facebook xxfld api xxfld 2 i i 'm trying to create a a blog on xxmaj that xxmaj xxmaj app api . xxmaj the i am to do the xxup . page xxmaj xxmaj the i click the the page on the , get the posts : \n\n xxmaj the can the facebook xxmaj a \n\n xxunk ) ) \n\n</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>( f.attributes xxmaj and xxunk ) = xxunk \n\n▁ xxmaj for xxmaj each file xxmaj in xxunk \n▁ xxunk = fileattributes.normal \n▁ xxmaj next \n\n▁ xxmaj if recursive xxmaj then \n\n▁ xxmaj for xxmaj each subdirectory xxmaj in xxunk ( ) \n▁ xxunk ) \n▁ xxmaj next \n\n▁ xxmaj end xxmaj if \n\n▁ xxmaj end xxmaj sub \n\n xxmaj end xxmaj module \n\n▁ xxfld 6 xxmaj tim xxmaj murphy xxfld 7 https</td>
#       <td>f.attributes xxmaj and xxunk ) = xxunk \n\n▁ xxmaj for xxmaj each file xxmaj in xxunk \n▁ xxunk = fileattributes.normal \n▁ xxmaj next \n\n▁ xxmaj if recursive xxmaj then \n\n▁ xxmaj for xxmaj each subdirectory xxmaj in xxunk ( ) \n▁ xxunk ) \n▁ xxmaj next \n\n▁ xxmaj end xxmaj if \n\n▁ xxmaj end xxmaj sub \n\n xxmaj end xxmaj module \n\n▁ xxfld 6 xxmaj tim xxmaj murphy xxfld 7 https :</td>
#       <td>xxunk - ) xxmaj ) ) xxunk ) xxfld xxunk example example xxmaj , i xxmaj , xxmaj = xxunk \n▁ xxunk xxunk \n▁ xxmaj xxunk xxunk xxmaj as \n▁ xxmaj if xxmaj example xxmaj \n▁ in xxmaj \n▁ ) \n▁ xxmaj ) \n▁ xxmaj xxunk \n▁ xxmaj if xxmaj with \n▁ xxmaj end xxmaj sub \n\n▁ xxmaj end xxmaj sub \n\n▁ xxfld 6 xxmaj xxunk xxmaj xxunk xxfld 7 https :</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>helps that , by using hardware support , the xxup vga / xxup dvi / xxup hdmi cable transports a tick signal that says " i flipped ! " , the graphic cards receives it , signal it to the xxup cpu with an interrupt ( most likely ) , and the driver gets it and communicate it to the currently waiting opengl / directx presenting threads . xxmaj this unleash a</td>
#       <td>that , by using hardware support , the xxup vga / xxup dvi / xxup hdmi cable transports a tick signal that says " i flipped ! " , the graphic cards receives it , signal it to the xxup cpu with an interrupt ( most likely ) , and the driver gets it and communicate it to the currently waiting opengl / directx presenting threads . xxmaj this unleash a fast</td>
#       <td>. you if making the , , i xxup xxunk / xxup vga / xxup vga interface can the lot signal to is " xxunk can " " . and " is are the , and the to the xxup pc , the xxup , or likely ) . and the xxup is stuck back the with with the xxup running xxup user xxup system user . \n\n the is a "</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>to why it is included in the system , it must be that the \n channel characteristics and system requirements are such that \n coherent detection of the signal is not thought to be feasible , \n and so the receiver is being implemented \n is a differentially coherent detector for xxup dqpsk ( differentially encoded \n xxup qpsk ) . xxmaj note that coherent detection requires that the receiver \n phase</td>
#       <td>why it is included in the system , it must be that the \n channel characteristics and system requirements are such that \n coherent detection of the signal is not thought to be feasible , \n and so the receiver is being implemented \n is a differentially coherent detector for xxup dqpsk ( differentially encoded \n xxup qpsk ) . xxmaj note that coherent detection requires that the receiver \n phase lock</td>
#       <td>the the is not in the xxup . and is be a the xxup xxunk is are the are are not that the xxmaj systems is the xxup is not possible of be a . but xxmaj the on xxup is not used . xxmaj the good xxunk system . the xxunk . or ) ) xxup xxunk ) \n xxmaj the that the xxup is a the xxup is xxunk xxup</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>persistent punishment for failure : xxmaj things like xxunk , loss of money / exp / stats on death , limited lives before having to restart the game ( that 's pretty outdated , but whatever ) . xxmaj so when the player gets stuck or comes up against a challenge that they are likely to fail , they have an incentive to skip part or all of this challenge using the</td>
#       <td>punishment for failure : xxmaj things like xxunk , loss of money / exp / stats on death , limited lives before having to restart the game ( that 's pretty outdated , but whatever ) . xxmaj so when the player gets stuck or comes up against a challenge that they are likely to fail , they have an incentive to skip part or all of this challenge using the super</td>
#       <td>session for the . \n\n\n▁ the like : , xxunk of xxunk , xxunk : channel , the , etc to , death to deal the game . which is not much ) and not you is xxmaj the , you user is back in xxunk back with the xxunk , is 're having to get , they are to opportunity to take the of even of the . . the xxmaj</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>} \n\n\n\n\n xxmaj the first and the second lines seem right ; perhaps , due to the low ‘ xxunk a negative shift is good , so the second line could be preferred . \n\n xxmaj in no case should the integrand go below the integration bounds . xxmaj so , starting from the third line the result are on the worse side . \n▁ xxfld 6 egreg xxfld 7 https :</td>
#       <td>\n\n\n\n\n xxmaj the first and the second lines seem right ; perhaps , due to the low ‘ xxunk a negative shift is good , so the second line could be preferred . \n\n xxmaj in no case should the integrand go below the integration bounds . xxmaj so , starting from the third line the result are on the worse side . \n▁ xxfld 6 egreg xxfld 7 https : /</td>
#       <td>\n\n xxmaj the problem time last second part are to , the the the to the fact - xxunk , number value is needed . but the xxunk is is be a . \n\n xxmaj the the case , you second be to the same rule , xxmaj the , if with the first line , second is not the right side . xxmaj xxfld 6 xxmaj xxfld 7 https : /</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td># read csv file \n csv_reader = csv.reader(open('test.csv ' , ' ru ' ) ) \n\n length_list = len(list(csv_reader ) ) \n value = [ ] \n\n for line in csv_reader : \n▁ xxunk ) # transfer contents of csv to list \n\n def find_voucher(input_voucher , counter ) : \n▁ while counter &lt; length_list : \n▁ check_voucher = input_voucher in value[counter ] \n▁ if check_voucher = = xxmaj true : \n▁ print</td>
#       <td>read csv file \n csv_reader = csv.reader(open('test.csv ' , ' ru ' ) ) \n\n length_list = len(list(csv_reader ) ) \n value = [ ] \n\n for line in csv_reader : \n▁ xxunk ) # transfer contents of csv to list \n\n def find_voucher(input_voucher , counter ) : \n▁ while counter &lt; length_list : \n▁ check_voucher = input_voucher in value[counter ] \n▁ if check_voucher = = xxmaj true : \n▁ print "</td>
#       <td>1 - file . xxmaj = xxunk ' ) ' xxunk ' ) ; ; xxunk = xxunk ) ) \n print = xxunk ] \n xxunk ( in line : \n▁ print = \n▁ 1 the of line file file \n▁ print xxunk , xxunk ) : \n▁ xxrep xxunk = = : value xxunk = xxunk in xxunk

# %%
learn.save_encoder('enc1')

# %%
from nbdev.export import notebook2script
notebook2script()
# Out:
# Converted 00_encoder.ipynb.
# Converted 01_decoder.ipynb.
# Converted index.ipynb.
