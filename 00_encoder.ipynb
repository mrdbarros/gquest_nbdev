# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# default_exp encoder

# %% [markdown]
# # Imports
#
# > API details.

# %%
#hide
from nbdev.showdoc import *
from fastcore.test import *

# %%
#export
import pandas as pd # package for high-performance, easy-to-use data structures and data analysis

import re

import string

from fastai2.basics import *
from fastai2.text.all import *
from fastai2.callback.all import *

# %%
#export
import os
print(os.listdir("../data/gquest_data/"))
data_path = Path("../data/gquest_data/")
# Out:
# ['sample_submission.csv', 'test', 'models', 'train', 'vocab.pkl']

# %%
import pdb

# %% [markdown]
# # Reading data

# %%
#export
print('Reading data...')
train_data = pd.read_csv(data_path/'train/train.csv')
test_data = pd.read_csv(data_path/'test/test.csv')
sample_submission = pd.read_csv(str(data_path/'sample_submission.csv'))
print('Reading data completed')
# Out:
# Reading data...
# Reading data completed

# %%
#export
print('Size of train_data', train_data.shape)
print('Size of test_data', test_data.shape)
print('Size of sample_submission', sample_submission.shape)
test_eq(train_data.shape,(6079,41))
test_eq(test_data.shape,(476,11))
test_eq(sample_submission.shape,(476,31))
# Out:
# Size of train_data (6079, 41)
# Size of test_data (476, 11)
# Size of sample_submission (476, 31)

# %%
train_data.head()
# Out:
#    qa_id  \
# 0      0
# 1      1
# 2      2
# 3      3
# 4      5
#
#                                                                                                  question_title  \
# 0                                          What am I losing when using extension tubes instead of a macro lens?
# 1  What is the distinction between a city and a sprawl/metroplex... between downtown and a commercial district?
# 2                                                      Maximum protusion length for through-hole component pins
# 3                                                                         Can an affidavit be used in Beit Din?
# 4                                                                  How do you make a binary image in Photoshop?
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              question_body  \
# 0  After playing around with macro photography on-the-cheap (read: reversed lens, rev. lens mounted on a straight lens, passive extension tubes), I would like to get further with this. The problems with the techniques I used is that focus is manual and aperture control is problematic at best. This limited my setup to still subjects (read: dead insects) Now, as spring is approaching, I want to be able to shoot live insects. I believe that for this, autofocus and settable aperture will be of great help.\n\nSo, one obvious but expensive option is a macro lens (say, EF 100mm Macro) However, I am ...
# 1  I am trying to understand what kinds of places the spam values on p 231 refer to in the 5th Edition main book for Shadowrun.\n\nPer p 15, a sprawl is a plex, a plex is a "metropolitan complex, short for metroplex". Per Google a metroplex is " a very large metropolitan area, especially one that is an aggregation of two or more cities".  A city downtown and sprawl downtown would tend to have similar densities, but for some reason the sprawl (which includes suburbs?) has a higher spam zone noise rating (p 231).  Similarly, I'd think of a downtown as being more dense and noisy (e.g. Office bui...
# 2  I'm working on a PCB that has through-hole components on both sides of the board. The "top" side of the board is mounted flush to a Delrin plastic block (the only top-side component is a gas sensor that is fed air samples through hose fittings in the plastic block).\n\nThe flush mounting means that I have to add grooves to the plastic block to accommodate the soldered pins of the bottom-side components. Assuming a standard 0.062" thickness FR4 board, how deep do I need to make the grooves in the plastic block? The only thing I could find is this NASA workmanship standard that states 0.5mm ...
# 3                                                                                                                                                                           An affidavit, from what i understand, is basically a signed document given by a witness to be used as evidence in a trial, without the witness themselves needing to take a stand.\n\nCan an affidavit be used in Beit Din? Or must witnesses take the stand in person for their testimony to count?\n\n(In case i'm misunderstanding what exactly an affidavit is, simply treat it as a signed document by a witness with their testimony.)\n
# 4                                                                                                                                                                                    I am trying to make a binary image. I want more than just the look of the image to be black/white, but I want the actual file to be a binary file. Every pixel should be either black, or white. \n\nI don't just want a monochrome image. I can't have varying shades of gray, every pixel needs to be black or white.\n\nIs this possible? I looked under Image > Mode but nothing there seems to indiciate a binary style image.\n
#
#   question_user_name                                   question_user_page  \
# 0               ysap           https://photo.stackexchange.com/users/1024
# 1      russellpierce             https://rpg.stackexchange.com/users/8774
# 2          Joe Baker    https://electronics.stackexchange.com/users/10157
# 3         Scimonster         https://judaism.stackexchange.com/users/5151
# 4            leigero  https://graphicdesign.stackexchange.com/users/21313
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     answer  \
# 0  I just got extension tubes, so here's the skinny.\n\n\n  ...what am I losing when using tubes...?\n\n\nA very considerable amount of light!  Increasing that distance from the end of the lens to the sensor can cut your light several stops.  Combined with the fact that you'll usually shoot stopped down - expect to need to increase your ISO considerably.\n\nThe fact the macro's are usually considered very very sharp, although I believe that 70-200mm 2.8 is supposed to be quite sharp.\n\nThe ultra low distortion typical of many macros.\n\nI wouldn't worry too much about the bokeh since the DOF...
# 1                                                                                                                                                 It might be helpful to look into the definition of spam zone:\n\n(p.216) spam zone: An area flooded with invasive and/or viral AR advertising, causing noise.\n\nBecause a metroplex has so many marketing targets, it seems a safe assumption that marketers would drown the plex with spam. Spam from the less dense areas would bleed into the urban cores. A smaller city with less urban/suburban territory surrounding it ostensibly wouldn't have as much spam.\n
# 2  Do you even need grooves?  We make several products using through-hole components that are intended to mount using VHB double-sided foam tape.  The boards are 0.062" thick double-sided with PTH and we use a table-top vertical belt sander to bring the component leads almost flush with the solder mask.  In other words, the solder mask isn't touched by the sand paper but the leads are all sanded flat and sitting just proud of the solder mask.\n\nThis works well for small boards.\n\nFor what it's worth, there are commercial machines available that use a rotary saw blade to do the same thing.  ...
# 3  Sending an "affidavit" it is a dispute between Rashi and Rabbeinu Tam.\n\nDevarim 19:15:\n\n\n  לא יקום עד אחד באיש לכל עון ולכל חטאת בכל חטא אשר יחטא על פי שני עדים או על פי שלשה עדים יקום דבר\n\n\nRashi:\n\n\n  ולא שיכתבו עדותם באגרת וישלחו לבית דין\n  \n  And not that they write their testimony in a letter and send it to Beis Din\n\n\nTosefos Bava Basra 40a (continued from 39b):\n\n\n  ועוד אומר ר"י ששמע מן ר"ת שנוהגים לשלח העדים עדותם באיגרת לב"ד וחשיב עדות והא דדרשינן בספרי. מפיהם ולא מפי כתבם לא אתא אלא למעוטי דוקא אלם שאינו בר הגדה אבל ראוי להגדה אין הגדה מעכבת בו \n  \n  R"i said t...
# 4                                                                                                                                                                                                                                                                                                                                                                               Check out Image Trace in Adobe Illustrator. \n\nI like using python and PIL, however.\n\nfrom PIL import Image\nimage_file = Image.open("myimage.bmp") \nimage_file = image_file.convert('1') # convert\nimage_file.save('result.bmp')\n\n
#
#   answer_user_name                                     answer_user_page  \
# 0           rfusca           https://photo.stackexchange.com/users/1917
# 1     Erik Schmidt             https://rpg.stackexchange.com/users/1871
# 2      Dwayne Reid    https://electronics.stackexchange.com/users/64754
# 3    Y     e     z         https://judaism.stackexchange.com/users/4794
# 4             q2ra  https://graphicdesign.stackexchange.com/users/27160
#
#                                                                                                                           url  \
# 0           http://photo.stackexchange.com/questions/9169/what-am-i-losing-when-using-extension-tubes-instead-of-a-macro-lens
# 1  http://rpg.stackexchange.com/questions/47820/what-is-the-distinction-between-a-city-and-a-sprawl-metroplex-between-downtow
# 2              http://electronics.stackexchange.com/questions/154225/maximum-protusion-length-for-through-hole-component-pins
# 3                                       http://judaism.stackexchange.com/questions/55182/can-an-affidavit-be-used-in-beit-din
# 4                          http://graphicdesign.stackexchange.com/questions/35791/how-do-you-make-a-binary-image-in-photoshop
#
#     category  ... question_well_written  answer_helpful  \
# 0  LIFE_ARTS  ...              1.000000        1.000000
# 1    CULTURE  ...              0.888889        0.888889
# 2    SCIENCE  ...              0.777778        0.777778
# 3    CULTURE  ...              0.888889        0.833333
# 4  LIFE_ARTS  ...              1.000000        1.000000
#
#    answer_level_of_information  answer_plausible  answer_relevance  \
# 0                     0.666667          1.000000          1.000000
# 1                     0.555556          0.888889          0.888889
# 2                     0.555556          1.000000          1.000000
# 3                     0.333333          0.833333          1.000000
# 4                     0.666667          1.000000          1.000000
#
#    answer_satisfaction  answer_type_instructions  answer_type_procedure  \
# 0             0.800000                       1.0               0.000000
# 1             0.666667                       0.0               0.000000
# 2             0.666667                       0.0               0.333333
# 3             0.800000                       0.0               0.000000
# 4             0.800000                       1.0               0.000000
#
#    answer_type_reason_explanation  answer_well_written
# 0                        0.000000             1.000000
# 1                        0.666667             0.888889
# 2                        1.000000             0.888889
# 3                        1.000000             1.000000
# 4                        1.000000             1.000000
#
# [5 rows x 41 columns]

# %%
train_data.columns
# Out:
# Index(['qa_id', 'question_title', 'question_body', 'question_user_name',
#        'question_user_page', 'answer', 'answer_user_name', 'answer_user_page',
#        'url', 'category', 'host', 'question_asker_intent_understanding',
#        'question_body_critical', 'question_conversational',
#        'question_expect_short_answer', 'question_fact_seeking',
#        'question_has_commonly_accepted_answer',
#        'question_interestingness_others', 'question_interestingness_self',
#        'question_multi_intent', 'question_not_really_a_question',
#        'question_opinion_seeking', 'question_type_choice',
#        'question_type_compare', 'question_type_consequence',
#        'question_type_definition', 'question_type_entity',
#        'question_type_instructions', 'question_type_procedure',
#        'question_type_reason_explanation', 'question_type_spelling',
#        'question_well_written', 'answer_helpful',
#        'answer_level_of_information', 'answer_plausible', 'answer_relevance',
#        'answer_satisfaction', 'answer_type_instructions',
#        'answer_type_procedure', 'answer_type_reason_explanation',
#        'answer_well_written'],
#       dtype='object')

# %%
sample_submission.columns
# Out:
# Index(['qa_id', 'question_asker_intent_understanding',
#        'question_body_critical', 'question_conversational',
#        'question_expect_short_answer', 'question_fact_seeking',
#        'question_has_commonly_accepted_answer',
#        'question_interestingness_others', 'question_interestingness_self',
#        'question_multi_intent', 'question_not_really_a_question',
#        'question_opinion_seeking', 'question_type_choice',
#        'question_type_compare', 'question_type_consequence',
#        'question_type_definition', 'question_type_entity',
#        'question_type_instructions', 'question_type_procedure',
#        'question_type_reason_explanation', 'question_type_spelling',
#        'question_well_written', 'answer_helpful',
#        'answer_level_of_information', 'answer_plausible', 'answer_relevance',
#        'answer_satisfaction', 'answer_type_instructions',
#        'answer_type_procedure', 'answer_type_reason_explanation',
#        'answer_well_written'],
#       dtype='object')

# %%
targets = list(sample_submission.columns[1:])
targets
# Out:
# ['question_asker_intent_understanding',
#  'question_body_critical',
#  'question_conversational',
#  'question_expect_short_answer',
#  'question_fact_seeking',
#  'question_has_commonly_accepted_answer',
#  'question_interestingness_others',
#  'question_interestingness_self',
#  'question_multi_intent',
#  'question_not_really_a_question',
#  'question_opinion_seeking',
#  'question_type_choice',
#  'question_type_compare',
#  'question_type_consequence',
#  'question_type_definition',
#  'question_type_entity',
#  'question_type_instructions',
#  'question_type_procedure',
#  'question_type_reason_explanation',
#  'question_type_spelling',
#  'question_well_written',
#  'answer_helpful',
#  'answer_level_of_information',
#  'answer_plausible',
#  'answer_relevance',
#  'answer_satisfaction',
#  'answer_type_instructions',
#  'answer_type_procedure',
#  'answer_type_reason_explanation',
#  'answer_well_written']

# %%
text_columns=['question_title', 'question_body', 'question_user_name',
       'question_user_page', 'answer', 'answer_user_name', 'answer_user_page',
       'url', 'category', 'host']

# %%
train_data[targets].describe()
# Out:
#        question_asker_intent_understanding  question_body_critical  \
# count                          6079.000000             6079.000000
# mean                              0.892663                0.595301
# std                               0.132047                0.219470
# min                               0.333333                0.333333
# 25%                               0.777778                0.444444
# 50%                               0.888889                0.555556
# 75%                               1.000000                0.777778
# max                               1.000000                1.000000
#
#        question_conversational  question_expect_short_answer  \
# count              6079.000000                   6079.000000
# mean                  0.057301                      0.698525
# std                   0.182196                      0.350938
# min                   0.000000                      0.000000
# 25%                   0.000000                      0.500000
# 50%                   0.000000                      0.666667
# 75%                   0.000000                      1.000000
# max                   1.000000                      1.000000
#
#        question_fact_seeking  question_has_commonly_accepted_answer  \
# count            6079.000000                            6079.000000
# mean                0.772633                               0.793689
# std                 0.303023                               0.336622
# min                 0.000000                               0.000000
# 25%                 0.666667                               0.666667
# 50%                 1.000000                               1.000000
# 75%                 1.000000                               1.000000
# max                 1.000000                               1.000000
#
#        question_interestingness_others  question_interestingness_self  \
# count                      6079.000000                    6079.000000
# mean                          0.587478                       0.507275
# std                           0.135900                       0.185987
# min                           0.333333                       0.333333
# 25%                           0.444444                       0.333333
# 50%                           0.555556                       0.444444
# 75%                           0.666667                       0.666667
# max                           1.000000                       1.000000
#
#        question_multi_intent  question_not_really_a_question  ...  \
# count            6079.000000                     6079.000000  ...
# mean                0.238745                        0.004469  ...
# std                 0.335057                        0.045782  ...
# min                 0.000000                        0.000000  ...
# 25%                 0.000000                        0.000000  ...
# 50%                 0.000000                        0.000000  ...
# 75%                 0.333333                        0.000000  ...
# max                 1.000000                        1.000000  ...
#
#        question_well_written  answer_helpful  answer_level_of_information  \
# count            6079.000000     6079.000000                  6079.000000
# mean                0.799931        0.925408                     0.654823
# std                 0.178420        0.114836                     0.107666
# min                 0.333333        0.333333                     0.333333
# 25%                 0.666667        0.888889                     0.666667
# 50%                 0.833333        1.000000                     0.666667
# 75%                 1.000000        1.000000                     0.666667
# max                 1.000000        1.000000                     1.000000
#
#        answer_plausible  answer_relevance  answer_satisfaction  \
# count       6079.000000       6079.000000          6079.000000
# mean           0.960054          0.968626             0.854680
# std            0.086926          0.074631             0.130743
# min            0.333333          0.333333             0.200000
# 25%            1.000000          1.000000             0.800000
# 50%            1.000000          1.000000             0.866667
# 75%            1.000000          1.000000             0.933333
# max            1.000000          1.000000             1.000000
#
#        answer_type_instructions  answer_type_procedure  \
# count               6079.000000            6079.000000
# mean                   0.479547               0.130641
# std                    0.422921               0.225718
# min                    0.000000               0.000000
# 25%                    0.000000               0.000000
# 50%                    0.500000               0.000000
# 75%                    1.000000               0.333333
# max                    1.000000               1.000000
#
#        answer_type_reason_explanation  answer_well_written
# count                     6079.000000          6079.000000
# mean                         0.502468             0.908254
# std                          0.407097             0.100708
# min                          0.000000             0.333333
# 25%                          0.000000             0.888889
# 50%                          0.500000             0.888889
# 75%                          1.000000             1.000000
# max                          1.000000             1.000000
#
# [8 rows x 30 columns]

# %%
train_data['question_body'][0]
# Out:
# 'After playing around with macro photography on-the-cheap (read: reversed lens, rev. lens mounted on a straight lens, passive extension tubes), I would like to get further with this. The problems with the techniques I used is that focus is manual and aperture control is problematic at best. This limited my setup to still subjects (read: dead insects) Now, as spring is approaching, I want to be able to shoot live insects. I believe that for this, autofocus and settable aperture will be of great help.\n\nSo, one obvious but expensive option is a macro lens (say, EF 100mm Macro) However, I am not really interested in yet another prime lens. An alternative is the electrical extension tubes.\n\nExcept for maximum focusing distance, what am I losing when using tubes (coupled with a fine lens, say EF70-200/2.8) instead of a macro lens?\n'

# %%
text_columns
# Out:
# ['question_title',
#  'question_body',
#  'question_user_name',
#  'question_user_page',
#  'answer',
#  'answer_user_name',
#  'answer_user_page',
#  'url',
#  'category',
#  'host']

# %%
df_tokenized,token_count=tokenize_df(train_data,text_columns)

# %%
df_tokenized.head()
# Out:
#    qa_id  question_asker_intent_understanding  question_body_critical  \
# 0      0                             1.000000                0.333333
# 1      1                             1.000000                1.000000
# 2      2                             0.888889                0.666667
# 3      3                             0.888889                0.666667
# 4      5                             1.000000                0.666667
#
#    question_conversational  question_expect_short_answer  \
# 0                 0.000000                           0.0
# 1                 0.000000                           0.5
# 2                 0.000000                           1.0
# 3                 0.666667                           1.0
# 4                 0.000000                           1.0
#
#    question_fact_seeking  question_has_commonly_accepted_answer  \
# 0                    0.0                                    0.0
# 1                    1.0                                    1.0
# 2                    1.0                                    1.0
# 3                    1.0                                    1.0
# 4                    1.0                                    1.0
#
#    question_interestingness_others  question_interestingness_self  \
# 0                         1.000000                       1.000000
# 1                         0.444444                       0.444444
# 2                         0.666667                       0.444444
# 3                         0.444444                       0.444444
# 4                         0.666667                       0.666667
#
#    question_multi_intent  ...  answer_helpful  answer_level_of_information  \
# 0               0.000000  ...        1.000000                     0.666667
# 1               0.666667  ...        0.888889                     0.555556
# 2               0.333333  ...        0.777778                     0.555556
# 3               0.000000  ...        0.833333                     0.333333
# 4               0.000000  ...        1.000000                     0.666667
#
#    answer_plausible  answer_relevance  answer_satisfaction  \
# 0          1.000000          1.000000             0.800000
# 1          0.888889          0.888889             0.666667
# 2          1.000000          1.000000             0.666667
# 3          0.833333          1.000000             0.800000
# 4          1.000000          1.000000             0.800000
#
#    answer_type_instructions  answer_type_procedure  \
# 0                       1.0               0.000000
# 1                       0.0               0.000000
# 2                       0.0               0.333333
# 3                       0.0               0.000000
# 4                       1.0               0.000000
#
#    answer_type_reason_explanation  answer_well_written  \
# 0                        0.000000             1.000000
# 1                        0.666667             0.888889
# 2                        1.000000             0.888889
# 3                        1.000000             1.000000
# 4                        1.000000             1.000000
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       text
# 0  [xxbos, xxfld, 1, xxmaj, what, am, i, losing, when, using, extension, tubes, instead, of, a, macro, lens, ?, xxfld, 2, xxmaj, after, playing, around, with, macro, photography, on, -, the, -, cheap, (, read, :, reversed, lens, ,, rev, ., lens, mounted, on, a, straight, lens, ,, passive, extension, tubes, ), ,, i, would, like, to, get, further, with, this, ., xxmaj, the, problems, with, the, techniques, i, used, is, that, focus, is, manual, and, aperture, control, is, problematic, at, best, ., xxmaj, this, limited, my, setup, to, still, subjects, (, read, :, dead, insects, ), xxmaj, now, ,, ...
# 1  [xxbos, xxfld, 1, xxmaj, what, is, the, distinction, between, a, city, and, a, sprawl, /, metroplex, …, between, downtown, and, a, commercial, district, ?, xxfld, 2, i, am, trying, to, understand, what, kinds, of, places, the, spam, values, on, p, 231, refer, to, in, the, 5th, xxmaj, edition, main, book, for, xxmaj, shadowrun, ., \n\n, xxmaj, per, p, 15, ,, a, sprawl, is, a, plex, ,, a, plex, is, a, ", metropolitan, complex, ,, short, for, metroplex, ", ., xxmaj, per, xxmaj, google, a, metroplex, is, ", a, very, large, metropolitan, area, ,, especially, one, that, is, an, aggregation, of, ...
# 2  [xxbos, xxfld, 1, xxmaj, maximum, protusion, length, for, through, -, hole, component, pins, xxfld, 2, xxmaj, i, 'm, working, on, a, xxup, pcb, that, has, through, -, hole, components, on, both, sides, of, the, board, ., xxmaj, the, ", top, ", side, of, the, board, is, mounted, flush, to, a, xxmaj, delrin, plastic, block, (, the, only, top, -, side, component, is, a, gas, sensor, that, is, fed, air, samples, through, hose, fittings, in, the, plastic, block, ), ., \n\n, xxmaj, the, flush, mounting, means, that, i, have, to, add, grooves, to, the, plastic, block, to, accommodate, the, solder...
# 3  [xxbos, xxfld, 1, xxmaj, can, an, affidavit, be, used, in, xxmaj, beit, xxmaj, din, ?, xxfld, 2, xxmaj, an, affidavit, ,, from, what, i, understand, ,, is, basically, a, signed, document, given, by, a, witness, to, be, used, as, evidence, in, a, trial, ,, without, the, witness, themselves, needing, to, take, a, stand, ., \n\n, xxmaj, can, an, affidavit, be, used, in, xxmaj, beit, xxmaj, din, ?, xxmaj, or, must, witnesses, take, the, stand, in, person, for, their, testimony, to, count, ?, \n\n, (, in, case, i, 'm, misunderstanding, what, exactly, an, affidavit, is, ,, simply, treat, it, as,...
# 4                                                     [xxbos, xxfld, 1, xxmaj, how, do, you, make, a, binary, image, in, xxmaj, photoshop, ?, xxfld, 2, i, am, trying, to, make, a, binary, image, ., i, want, more, than, just, the, look, of, the, image, to, be, black, /, white, ,, but, i, want, the, actual, file, to, be, a, binary, file, ., xxmaj, every, pixel, should, be, either, black, ,, or, white, ., \n\n, i, do, n't, just, want, a, monochrome, image, ., i, ca, n't, have, varying, shades, of, gray, ,, every, pixel, needs, to, be, black, or, white, ., \n\n, xxmaj, is, this, possible, ?, i, ...]
#
# [5 rows x 32 columns]

# %%
vocab = make_vocab(token_count)
vocab
# Out:
# ['xxunk',
#  'xxpad',
#  'xxbos',
#  'xxeos',
#  'xxfld',
#  'xxrep',
#  'xxwrep',
#  'xxup',
#  'xxmaj',
#  '/',
#  'the',
#  ',',
#  '-',
#  '.',
#  'to',
#  '\n▁',
#  'a',
#  ':',
#  ')',
#  'i',
#  'is',
#  '\n\n',
#  'and',
#  'of',
#  '"',
#  '(',
#  'in',
#  '\n',
#  'it',
#  'that',
#  '\\',
#  'you',
#  '$',
#  'for',
#  ';',
#  'this',
#  '?',
#  '=',
#  'users',
#  'https',
#  '}',
#  "'",
#  'with',
#  'on',
#  'be',
#  '3',
#  '1',
#  'if',
#  '>',
#  'have',
#  'as',
#  'not',
#  'can',
#  'are',
#  '<',
#  '2',
#  '{',
#  'or',
#  'but',
#  'do',
#  '\n\n\n',
#  '4',
#  'http',
#  'from',
#  '5',
#  'my',
#  "'s",
#  "n't",
#  '10',
#  '6',
#  'an',
#  ']',
#  '7',
#  '8',
#  'questions',
#  '9',
#  '\n\n▁',
#  'so',
#  'how',
#  'what',
#  'at',
#  'your',
#  'there',
#  'will',
#  'would',
#  'stackoverflow.com',
#  'by',
#  'use',
#  'one',
#  'when',
#  'which',
#  'like',
#  'all',
#  '0',
#  'some',
#  'does',
#  '&',
#  'get',
#  'any',
#  'using',
#  'they',
#  'then',
#  '[',
#  'was',
#  '*',
#  'just',
#  'more',
#  'should',
#  'has',
#  '+',
#  'we',
#  'other',
#  'want',
#  '#',
#  "'m",
#  'need',
#  'only',
#  'way',
#  'no',
#  'about',
#  'am',
#  'up',
#  'time',
#  'also',
#  'new',
#  'out',
#  'could',
#  'technology',
#  'code',
#  '…',
#  'where',
#  'me',
#  'make',
#  '!',
#  'file',
#  'here',
#  'same',
#  'than',
#  'them',
#  'know',
#  'into',
#  'work',
#  'two',
#  'set',
#  'data',
#  'see',
#  'because',
#  '\n\n\n▁',
#  'first',
#  'why',
#  'question',
#  'after',
#  'used',
#  'example',
#  'now',
#  'these',
#  'find',
#  'their',
#  'function',
#  '%',
#  '_',
#  'problem',
#  'he',
#  "'ve",
#  'something',
#  'x',
#  'good',
#  'even',
#  'user',
#  'page',
#  'very',
#  'each',
#  'may',
#  'different',
#  'been',
#  'server',
#  'think',
#  'right',
#  'return',
#  'such',
#  'c',
#  'much',
#  'class',
#  'most',
#  'between',
#  'another',
#  'value',
#  'its',
#  'stackoverflow',
#  'add',
#  'since',
#  'list',
#  'did',
#  'go',
#  'however',
#  'still',
#  'error',
#  '|',
#  'string',
#  'number',
#  'name',
#  'd',
#  'help',
#  'case',
#  'without',
#  'possible',
#  'create',
#  'had',
#  'well',
#  'end',
#  'system',
#  'while',
#  'might',
#  'before',
#  'many',
#  'public',
#  'line',
#  'try',
#  'change',
#  'following',
#  'etc',
#  'really',
#  'ca',
#  'through',
#  'say',
#  'being',
#  'take',
#  'over',
#  "'re",
#  'answer',
#  'text',
#  'image',
#  '\n\n\n\n',
#  'who',
#  'both',
#  'people',
#  'table',
#  'files',
#  'point',
#  'int',
#  'culture',
#  'were',
#  'b',
#  'run',
#  'type',
#  'back',
#  'better',
#  'else',
#  'trying',
#  'too',
#  'look',
#  'field',
#  'key',
#  'able',
#  'sure',
#  'off',
#  'start',
#  'english.stackexchange.com',
#  'current',
#  'superuser.com',
#  'going',
#  'read',
#  'best',
#  'seems',
#  'electronics.stackexchange.com',
#  'things',
#  'method',
#  'every',
#  'down',
#  'found',
#  'script',
#  'w',
#  'edit',
#  'access',
#  'left',
#  'site',
#  'application',
#  'serverfault.com',
#  'let',
#  'looking',
#  'his',
#  'those',
#  "'d",
#  'part',
#  'android',
#  'science',
#  'size',
#  'update',
#  'long',
#  'y',
#  '--',
#  'object',
#  'output',
#  'working',
#  'works',
#  'array',
#  'select',
#  'running',
#  'true',
#  'lot',
#  'our',
#  'instead',
#  'form',
#  'check',
#  'php',
#  'actually',
#  'show',
#  'windows',
#  'information',
#  "'ll",
#  'app',
#  'math.stackexchange.com',
#  'order',
#  'word',
#  'though',
#  'give',
#  'second',
#  'put',
#  'thanks',
#  'above',
#  'source',
#  'own',
#  'simple',
#  'less',
#  'version',
#  'tried',
#  'around',
#  'life_arts',
#  'solution',
#  'done',
#  'having',
#  'always',
#  's',
#  'bit',
#  'var',
#  'times',
#  'database',
#  'based',
#  'already',
#  'given',
#  'thing',
#  'again',
#  'power',
#  'call',
#  'either',
#  'values',
#  'post',
#  'probably',
#  'doing',
#  'div',
#  'result',
#  'e',
#  'non',
#  'option',
#  'group',
#  'must',
#  'physics.stackexchange.com',
#  'view',
#  'last',
#  'few',
#  'game',
#  'input',
#  '\n▁\n▁',
#  'never',
#  'means',
#  'open',
#  'link',
#  'level',
#  'null',
#  'mean',
#  'specific',
#  'f',
#  'command',
#  'web',
#  'issue',
#  'write',
#  'understand',
#  '..',
#  'note',
#  'single',
#  'n',
#  'high',
#  'top',
#  'correct',
#  'small',
#  'content',
#  'difference',
#  'please',
#  'someone',
#  'idea',
#  'enough',
#  'getting',
#  'anyone',
#  'multiple',
#  'least',
#  'made',
#  'button',
#  'p',
#  'next',
#  'query',
#  'm',
#  'default',
#  'message',
#  'called',
#  'space',
#  'tex.stackexchange.com',
#  'anything',
#  'once',
#  'install',
#  'similar',
#  'below',
#  'got',
#  'far',
#  'device',
#  't',
#  'side',
#  'said',
#  'service',
#  'us',
#  'project',
#  'keep',
#  'reason',
#  'process',
#  'network',
#  'wrong',
#  'test',
#  'google',
#  'simply',
#  'often',
#  'old',
#  'little',
#  'tell',
#  'main',
#  'column',
#  'images',
#  'path',
#  'kind',
#  'remove',
#  'quite',
#  'display',
#  'voltage',
#  'sql',
#  'static',
#  'usually',
#  'course',
#  'hard',
#  'html',
#  'fine',
#  'askubuntu.com',
#  'programmers.stackexchange.com',
#  'custom',
#  'results',
#  'makes',
#  'available',
#  'r',
#  'under',
#  'rpg.stackexchange.com',
#  'void',
#  'place',
#  'state',
#  'per',
#  'points',
#  'created',
#  'url',
#  'large',
#  'real',
#  'false',
#  'local',
#  'bad',
#  'maybe',
#  'via',
#  'book',
#  'machine',
#  'general',
#  'print',
#  'full',
#  'control',
#  'making',
#  'save',
#  'home',
#  'rather',
#  'reference',
#  'water',
#  'e.g.',
#  'standard',
#  'wo',
#  'free',
#  'click',
#  'log',
#  'inside',
#  'player',
#  'original',
#  'computer',
#  'g',
#  'java',
#  'whether',
#  'product',
#  'energy',
#  'words',
#  'color',
#  '100',
#  'gaming.stackexchange.com',
#  'seem',
#  'map',
#  'fact',
#  'search',
#  'common',
#  'address',
#  'allow',
#  'him',
#  'title',
#  'within',
#  'load',
#  'certain',
#  'model',
#  'unix.stackexchange.com',
#  'likely',
#  'design',
#  'program',
#  'options',
#  'drive',
#  'sense',
#  'memory',
#  'email',
#  'three',
#  'yes',
#  'date',
#  'come',
#  'looks',
#  'apple.stackexchange.com',
#  'mode',
#  'person',
#  'particular',
#  'low',
#  'element',
#  'uses',
#  'block',
#  'private',
#  'package',
#  'consider',
#  'javascript',
#  'says',
#  'client',
#  'until',
#  'security',
#  'everything',
#  'academia.stackexchange.com',
#  'changes',
#  'whole',
#  'photo.stackexchange.com',
#  'store',
#  'settings',
#  'easy',
#  'lines',
#  'several',
#  'items',
#  'ubuntu',
#  'years',
#  'include',
#  'pretty',
#  'software',
#  'domain',
#  'yet',
#  'i.e.',
#  'light',
#  'window',
#  'her',
#  'exactly',
#  'world',
#  'drupal.stackexchange.com',
#  'she',
#  'needs',
#  'related',
#  'variable',
#  'required',
#  'move',
#  'connection',
#  '^',
#  'account',
#  'diy.stackexchange.com',
#  'ux.stackexchange.com',
#  'event',
#  'during',
#  'play',
#  'gets',
#  'instance',
#  'important',
#  'scifi.stackexchange.com',
#  'password',
#  'linux',
#  'background',
#  'item',
#  'directory',
#  'objects',
#  'send',
#  'range',
#  'numbers',
#  'sort',
#  'echo',
#  'screen',
#  'clear',
#  'switch',
#  'force',
#  'import',
#  'setting',
#  'card',
#  'day',
#  'nothing',
#  'great',
#  'body',
#  'security.stackexchange.com',
#  'students',
#  'big',
#  'paper',
#  'build',
#  'mail',
#  'circuit',
#  'python',
#  '12',
#  'ask',
#  'character',
#  'index',
#  'short',
#  'term',
#  'against',
#  'adding',
#  'seen',
#  'normal',
#  'filter',
#  'style',
#  'effect',
#  'reading',
#  'itself',
#  'hand',
#  'disk',
#  'god',
#  '“',
#  'close',
#  'thought',
#  '”',
#  'hit',
#  'meaning',
#  'rules',
#  'position',
#  'turn',
#  'language',
#  'problems',
#  'added',
#  'english',
#  'others',
#  'box',
#  'final',
#  'car',
#  'mm',
#  'ell.stackexchange.com',
#  'fields',
#  'currently',
#  'loop',
#  'sometimes',
#  'api',
#  'functions',
#  '`',
#  'support',
#  'format',
#  'due',
#  'comes',
#  'gamedev.stackexchange.com',
#  'white',
#  'length',
#  'document',
#  'takes',
#  'folder',
#  'methods',
#  'job',
#  'basic',
#  '20',
#  'mathoverflow.net',
#  'stop',
#  'figure',
#  'delete',
#  'website',
#  'fix',
#  'dev',
#  'wordpress.stackexchange.com',
#  'k',
#  'later',
#  'days',
#  'answers',
#  'menu',
#  'os',
#  'choose',
#  'head',
#  'attack',
#  'action',
#  'amount',
#  'bottom',
#  'library',
#  'directly',
#  'company',
#  'matter',
#  'copy',
#  'especially',
#  'thus',
#  'needed',
#  'although',
#  'magento.stackexchange.com',
#  'comment',
#  'elements',
#  'gives',
#  'ip',
#  'year',
#  'vector',
#  'mechanics.stackexchange.com',
#  'node',
#  'area',
#  'creating',
#  'assume',
#  'speed',
#  'bytes',
#  'ok',
#  'def',
#  'installed',
#  'away',
#  'sound',
#  'stack',
#  'provide',
#  'z',
#  'black',
#  'pi',
#  'graphicdesign.stackexchange.com',
#  'root',
#  'therefore',
#  'links',
#  'row',
#  'td',
#  'across',
#  'engine',
#  'pages',
#  'shows',
#  'front',
#  'pass',
#  'terms',
#  'approach',
#  'bicycles.stackexchange.com',
#  'money.stackexchange.com',
#  'connected',
#  'zero',
#  'insert',
#  'xml',
#  'cause',
#  'feel',
#  'property',
#  'examples',
#  'goes',
#  'experience',
#  'rest',
#  'module',
#  'stuff',
#  'camera',
#  'research',
#  'rule',
#  'ways',
#  'connect',
#  'apply',
#  'properties',
#  'remember',
#  'section',
#  'useful',
#  'none',
#  'complete',
#  'performance',
#  'money',
#  'completely',
#  'mysql',
#  'signal',
#  'according',
#  'port',
#  'travel.stackexchange.com',
#  'mathematica.stackexchange.com',
#  'total',
#  'cases',
#  'label',
#  'started',
#  '11',
#  'draw',
#  'comments',
#  'basically',
#  'longer',
#  'revision',
#  'known',
#  'replace',
#  'higher',
#  'configuration',
#  'context',
#  'response',
#  'defined',
#  'whatever',
#  'hash',
#  'article',
#  'gis.stackexchange.com',
#  'h',
#  'session',
#  'perhaps',
#  'browser',
#  'guess',
#  'thinking',
#  'changed',
#  'missing',
#  'count',
#  'manager',
#  'programming',
#  'lens',
#  'actual',
#  'buy',
#  'template',
#  'starting',
#  'dba.stackexchange.com',
#  'avoid',
#  'feature',
#  'boardgames.stackexchange.com',
#  'cooking.stackexchange.com',
#  'step',
#  'double',
#  'request',
#  'allows',
#  'damage',
#  'generally',
#  'sudo',
#  'handle',
#  'css',
#  'contains',
#  'red',
#  'setup',
#  'happens',
#  'business',
#  'self',
#  'changing',
#  'games',
#  'otherwise',
#  'extra',
#  'tool',
#  'judaism.stackexchange.com',
#  'law',
#  'desktop',
#  'unless',
#  'special',
#  're',
#  '15',
#  'jquery',
#  'parts',
#  'theory',
#  'hope',
#  'frame',
#  'existing',
#  'playing',
#  'music.stackexchange.com',
#  '30',
#  'info',
#  'solve',
#  'online',
#  'boot',
#  'believe',
#  'statement',
#  'issues',
#  'choice',
#  'outside',
#  'languages',
#  'random',
#  'easier',
#  'room',
#  'cost',
#  'suggest',
#  'plugin',
#  'v',
#  'wondering',
#  'mind',
#  'players',
#  'sharepoint.stackexchange.com',
#  'correctly',
#  'books',
#  'selected',
#  'follow',
#  'require',
#  'bike',
#  'distance',
#  'devices',
#  'present',
#  'easily',
#  'child',
#  'explain',
#  '50',
#  'almost',
#  'rate',
#  'vs',
#  'bin',
#  'further',
#  'writing',
#  'written',
#  'asked',
#  'applications',
#  'depends',
#  'house',
#  'probability',
#  'live',
#  'tree',
#  'define',
#  'couple',
#  'contain',
#  'minutes',
#  'login',
#  'john',
#  'determine',
#  'break',
#  'exception',
#  'ones',
#  'environment',
#  'returns',
#  'meta.stackexchange.com',
#  'tag',
#  'battery',
#  'variables',
#  'separate',
#  'classes',
#  'usr',
#  'location',
#  'price',
#  'phone',
#  'asking',
#  'task',
#  'fixed',
#  'expect',
#  'recently',
#  'happen',
#  'types',
#  'ideas',
#  'base',
#  'along',
#  'structure',
#  'various',
#  'width',
#  'columns',
#  '2013',
#  'life',
#  'limit',
#  'thread',
#  'sentence',
#  'empty',
#  '’s',
#  'host',
#  'details',
#  'volume',
#  'situation',
#  'assuming',
#  'future',
#  'previous',
#  'names',
#  'deal',
#  'download',
#  'description',
#  'series',
#  'wanted',
#  'sites',
#  'usb',
#  'moving',
#  'customer',
#  'depending',
#  'christianity.stackexchange.com',
#  'l',
#  'negative',
#  'specifically',
#  'share',
#  'mark',
#  'layer',
#  'taking',
#  'equivalent',
#  'came',
#  'mac',
#  'including',
#  'li',
#  'considered',
#  'definition',
#  'gb',
#  'match',
#  'bar',
#  'mentioned',
#  '200',
#  'additional',
#  'oil',
#  'necessary',
#  'positive',
#  'automatically',
#  'together',
#  'prevent',
#  'ever',
#  'tools',
#  'earth',
#  'chain',
#  'learn',
#  'algorithm',
#  '24',
#  ...]

# %%
import pickle
with open(data_path/'vocab.pkl', 'wb') as vocab_file:
 
    pickle.dump(vocab, vocab_file)

# %%
tfm = Numericalize(make_vocab(token_count))

# %%
splits = RandomSplitter()(df_tokenized)

# %%
splits
# Out:
# ((#4864) [1602,1987,6039,4732,1617,3820,1093,2290,818,4556...],
#  (#1215) [5193,2727,283,1559,3203,6041,5969,4237,2686,5864...])

# %%
dsrc = DataSource(df_tokenized, [[attrgetter("text"), tfm]], splits=splits, dl_type=LMDataLoader)

# %%
bs,sl = 10,100
dbch = dsrc.databunch(bs=bs, seq_len=sl, after_batch=Cuda)

# %%
dbch.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#       <th>text_</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>xxbos xxfld 1 xxmaj what if i have a voltage between ground neutral ? xxfld 2 xxmaj what does it mean when there is voltage between ground and neutral ( 220v ) and between phase and neutral ( 220v ) but no voltage between phase and ground ( 0v ) ? \n\n xxmaj what could happen ? xxmaj is it safe ? \n\n xxmaj is it normal that when i plug in a lamp , it works just fine ? \n▁ xxfld 3 xxunk xxfld 4 https : / / electronics.stackexchange.com / users / xxunk xxfld 5 xxmaj what you</td>
#       <td>xxfld 1 xxmaj what if i have a voltage between ground neutral ? xxfld 2 xxmaj what does it mean when there is voltage between ground and neutral ( 220v ) and between phase and neutral ( 220v ) but no voltage between phase and ground ( 0v ) ? \n\n xxmaj what could happen ? xxmaj is it safe ? \n\n xxmaj is it normal that when i plug in a lamp , it works just fine ? \n▁ xxfld 3 xxunk xxfld 4 https : / / electronics.stackexchange.com / users / xxunk xxfld 5 xxmaj what you have</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>one typing xxrep 3 w xxunk / robots.txt . \n\n xxmaj as per the following google group post , the user specifies that by setting file permission to 640 , it 's possible to deny access to robots.txt file by the world but still enable search engine robots to read them . \n\n xxmaj is that true ? xxmaj if not how it 's possible to deny general public access to robots.txt but still allow xxmaj search engine robots to read them . \n▁ xxfld 3 xxunk xxfld 4 https : / / webmasters.stackexchange.com / users / xxunk xxfld 5</td>
#       <td>typing xxrep 3 w xxunk / robots.txt . \n\n xxmaj as per the following google group post , the user specifies that by setting file permission to 640 , it 's possible to deny access to robots.txt file by the world but still enable search engine robots to read them . \n\n xxmaj is that true ? xxmaj if not how it 's possible to deny general public access to robots.txt but still allow xxmaj search engine robots to read them . \n▁ xxfld 3 xxunk xxfld 4 https : / / webmasters.stackexchange.com / users / xxunk xxfld 5 xxmaj</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>and that cardinality does n't get preserved throughout the system , especially when data is passed as xxunk and / or serialized ( json , jsonp , xml , yaml ) . \n▁ xxfld 3 xxmaj niklas xxmaj xxunk xxfld 4 https : / / programmers.stackexchange.com / users / xxunk xxfld 5 i would call it cardinality ( and indeed i have used it in that sense ) . xxmaj it is strictly the cardinality of the set of all values a variable can take . \n\n xxmaj edit : for example , a 16-bit integer can take exactly xxunk</td>
#       <td>that cardinality does n't get preserved throughout the system , especially when data is passed as xxunk and / or serialized ( json , jsonp , xml , yaml ) . \n▁ xxfld 3 xxmaj niklas xxmaj xxunk xxfld 4 https : / / programmers.stackexchange.com / users / xxunk xxfld 5 i would call it cardinality ( and indeed i have used it in that sense ) . xxmaj it is strictly the cardinality of the set of all values a variable can take . \n\n xxmaj edit : for example , a 16-bit integer can take exactly xxunk values</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>xxfld 1 xxmaj illegal assignment from xxup list to xxup set xxfld 2 i am trying to query records and collect them in a xxmaj set as below \n\n xxmaj set &lt; xxunk &gt; a = [ select i d from xxunk limit 2 ] ; \n\n\n but getting the following error xxmaj illegal assignment from xxup list to xxunk i collect the result of a query in xxmaj set ? \n▁ xxfld 3 xxunk xxfld 4 https : / / salesforce.stackexchange.com / users / xxunk xxfld 5 xxmaj there is simple way : \n\n set &lt; account &gt; xxunk</td>
#       <td>1 xxmaj illegal assignment from xxup list to xxup set xxfld 2 i am trying to query records and collect them in a xxmaj set as below \n\n xxmaj set &lt; xxunk &gt; a = [ select i d from xxunk limit 2 ] ; \n\n\n but getting the following error xxmaj illegal assignment from xxup list to xxunk i collect the result of a query in xxmaj set ? \n▁ xxfld 3 xxunk xxfld 4 https : / / salesforce.stackexchange.com / users / xxunk xxfld 5 xxmaj there is simple way : \n\n set &lt; account &gt; xxunk =</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>' unit : " - " ' ? \n▁ xxfld 3 larifari xxfld 4 https : / / physics.stackexchange.com / users / xxunk xxfld 5 xxmaj the number $ 1 $ may be xxunk described as " unity " . xxmaj this very number is the original source of various words in the terminology , like the " unit matrix " ( a matrix behaving like the number $ 1 $ ) . \n\n xxmaj it is a convention to write down that dimensionless quantities like the xxmaj mach number have units $ 1 $ because the multiplication by $</td>
#       <td>unit : " - " ' ? \n▁ xxfld 3 larifari xxfld 4 https : / / physics.stackexchange.com / users / xxunk xxfld 5 xxmaj the number $ 1 $ may be xxunk described as " unity " . xxmaj this very number is the original source of various words in the terminology , like the " unit matrix " ( a matrix behaving like the number $ 1 $ ) . \n\n xxmaj it is a convention to write down that dimensionless quantities like the xxmaj mach number have units $ 1 $ because the multiplication by $ 1</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>exactly who the murderer is . \n\n xxmaj and digging into the emails and other records will reveal that the three were engaged in shady business deals , where the murderer was getting the short end of the stick . \n▁ xxfld 6 xxmaj rubberduck xxfld 7 https : / / rpg.stackexchange.com / users / xxunk xxfld 8 http : / / rpg.stackexchange.com / questions / 50671 / how - can - i - learn - how - to - lay - out - an - evidence - scene xxfld 9 xxup culture xxfld 10 rpg.stackexchange.com xxbos xxfld 1 xxmaj</td>
#       <td>who the murderer is . \n\n xxmaj and digging into the emails and other records will reveal that the three were engaged in shady business deals , where the murderer was getting the short end of the stick . \n▁ xxfld 6 xxmaj rubberduck xxfld 7 https : / / rpg.stackexchange.com / users / xxunk xxfld 8 http : / / rpg.stackexchange.com / questions / 50671 / how - can - i - learn - how - to - lay - out - an - evidence - scene xxfld 9 xxup culture xxfld 10 rpg.stackexchange.com xxbos xxfld 1 xxmaj remove</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>\n▁ join : function ( ) { \n▁ var xxunk = xxunk ] ; \n▁ if ( xxunk ) \n▁ xxunk xxmaj date ( ) } ) ; \n▁ else \n▁ xxunk xxunk : xxunk ) } ) ; \n▁ } \n ) } ; \n\n\n xxmaj do n't want to change the server doc ? xxmaj that 's okay , but conceptually a chat join is n't a chat message . xxmaj so you should definitely have a meta field for stuff like this in your chat documents . \n\n xxmaj but supposing you do n't want to do</td>
#       <td>join : function ( ) { \n▁ var xxunk = xxunk ] ; \n▁ if ( xxunk ) \n▁ xxunk xxmaj date ( ) } ) ; \n▁ else \n▁ xxunk xxunk : xxunk ) } ) ; \n▁ } \n ) } ; \n\n\n xxmaj do n't want to change the server doc ? xxmaj that 's okay , but conceptually a chat join is n't a chat message . xxmaj so you should definitely have a meta field for stuff like this in your chat documents . \n\n xxmaj but supposing you do n't want to do that</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>dip / dent in the blanket and so if you put another object with less mass it will roll down the dip onto the bigger mass . xxmaj is this true and is this what causes the centripetal force . \n▁ xxfld 3 xxmaj jonathan . xxfld 4 https : / / physics.stackexchange.com / users / 4 xxfld 5 xxmaj simple answer : gravity is a centripetal force , and can be xxunk clearly as such in xxmaj newtonian mechanics . \n\n xxmaj centripetal just means a force that is " xxunk inwards " ( " directed towards the centre</td>
#       <td>/ dent in the

# %%
config = awd_lstm_lm_config.copy()
config.update({'input_p': 0.6, 'output_p': 0.4, 'weight_p': 0.5, 'embed_p': 0.1, 'hidden_p': 0.2})
model = get_language_model(AWD_LSTM, len(vocab), config=config)

# %%
opt_func = partial(Adam, wd=0.1, eps=1e-7)
cb_funcs = [partial(MixedPrecision, clip=0.1), partial(RNNTrainer, alpha=2, beta=1)]

# %%
learn = Learner(dbch, model, loss_func=CrossEntropyLossFlat(), opt_func=opt_func, cb_funcs=cb_funcs, metrics=[accuracy, Perplexity()])

# %%
learn = language_model_learner(dbch, AWD_LSTM, metrics=[accuracy, Perplexity()], path=data_path, opt_func = partial(Adam, wd=0.1)).to_fp16()

# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %%
learn.freeze()
learn.fit_one_cycle(1, 1e-2, moms=(0.8,0.7,0.8))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.393530</td>
#       <td>3.814837</td>
#       <td>0.348596</td>
#       <td>45.369381</td>
#       <td>10:16</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.unfreeze()
learn.fit_one_cycle(4, 1e-2, moms=(0.8,0.7,0.8))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.143063</td>
#       <td>4.149327</td>
#       <td>0.330501</td>
#       <td>63.391312</td>
#       <td>12:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.996690</td>
#       <td>3.961744</td>
#       <td>0.347386</td>
#       <td>52.548897</td>
#       <td>12:08</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.675623</td>
#       <td>3.647782</td>
#       <td>0.380549</td>
#       <td>38.389427</td>
#       <td>12:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.415050</td>
#       <td>3.538444</td>
#       <td>0.393240</td>
#       <td>34.413315</td>
#       <td>12:05</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.show_results()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>input</th>
#       <th>target</th>
#       <th>pred</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>xxbos xxfld 1 xxmaj can you book hotels on a prepaid credit card worldwide ? xxfld 2 i tend to stay at smaller xxunk hotels or local apartments when i visit a city but recently due to some credit card issues i will need to depend on prepaid xxmaj visa . xxmaj but i noticed when i try to shop online a lot of retailers do n't accept prepaid credit cards so xxmaj i 'm thinking hotels would be even stricter . xxmaj is there a list somewhere of countries or particular hotel chains than ban prepaid cards ? xxmaj</td>
#       <td>xxfld 1 xxmaj can you book hotels on a prepaid credit card worldwide ? xxfld 2 i tend to stay at smaller xxunk hotels or local apartments when i visit a city but recently due to some credit card issues i will need to depend on prepaid xxmaj visa . xxmaj but i noticed when i try to shop online a lot of retailers do n't accept prepaid credit cards so xxmaj i 'm thinking hotels would be even stricter . xxmaj is there a list somewhere of countries or particular hotel chains than ban prepaid cards ? xxmaj if</td>
#       <td>xxfld 1 xxmaj how i use a in a website visa card ? ? xxfld 2 xxmaj am to have in the price , , a xxunk . i have a website . i i to the of card i . would be to buy on the money xxunk , xxmaj i i do that i took to buy my , lot of money , n't have the money cards . i i 'd not about are be more better . \n\n i there a way of that the that companies banks flights that the flights flights ? \n▁ if</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>xxmaj dead - tree types have some benefits like looking good on a bookshelf , but any ebook reader weighs less with 100 novels than the usual hard - cover book . \n xxmaj if you want to look for the damage of xxmaj ares xxmaj alpha , even with a half - decent tablet it takes less than 2 seconds . \n xxmaj digital copies do not get worn , they never get unwanted earmarks , but you can bookmark them . \n xxmaj rulebooks do get updates , and unless you are willing to take a pen to</td>
#       <td>dead - tree types have some benefits like looking good on a bookshelf , but any ebook reader weighs less with 100 novels than the usual hard - cover book . \n xxmaj if you want to look for the damage of xxmaj ares xxmaj alpha , even with a half - decent tablet it takes less than 2 seconds . \n xxmaj digital copies do not get worn , they never get unwanted earmarks , but you can bookmark them . \n xxmaj rulebooks do get updates , and unless you are willing to take a pen to your</td>
#       <td>xxunk xxmaj xxmaj xxmaj of a properties . this at . the xxmaj . but i other reader weighs less with a novels than the usual hard - cover book . \n\n xxmaj the you want to make at a same of the ares xxmaj alpha , you if a half - decent tablet , will less than 2 seconds . xxmaj xxmaj the copies are n't have worn , but will have a earmarks . but they can not them . xxmaj xxmaj if are n't a , but you you are going to buy a pen , the</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>there are services that can be enabled / disabled using the xxup gui ( like the startup application ) and then other ways of doing the same through the terminal . \n\n xxmaj for the xxmaj terminal you have several options . xxmaj open a terminal ( type " terminal " in the dash for example and open it ) and keep on reading : \n\n xxmaj enabling / xxmaj disabling a service \n\n xxmaj to toggle a service from starting or stopping permanently you would need to : \n\n echo manual | sudo tee / etc / init /</td>
#       <td>are services that can be enabled / disabled using the xxup gui ( like the startup application ) and then other ways of doing the same through the terminal . \n\n xxmaj for the xxmaj terminal you have several options . xxmaj open a terminal ( type " terminal " in the dash for example and open it ) and keep on reading : \n\n xxmaj enabling / xxmaj disabling a service \n\n xxmaj to toggle a service from starting or stopping permanently you would need to : \n\n echo manual | sudo tee / etc / init / xxunk</td>
#       <td>is no that are be used by removed . the xxmaj xxunk . or the following code ) . the use xxup to doing this same thing the xxup . \n\n xxmaj the example first xxunk , can to options : xxmaj the the terminal on or of xxunk " ) the terminal ) the ) " the in . then the the the \n\n xxmaj the a usr library / xxmaj on xxmaj the install the xxmaj , the to again the , can need to run \n\n sudo " " grep apt | dev / xxunk / xxunk</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>\n▁ } \n\n▁ # xxmaj check xxmaj web xxmaj application xxmaj policies \n▁ $ xxunk get - xxunk $ xxunk \n\n▁ foreach ( $ policy in $ xxunk ) \n▁ { \n▁ # xxmaj check if the search users is member of the group \n▁ xxunk -eq $ searchuser ) \n▁ { \n▁ # write - host $ xxunk \n▁ $ xxunk ( ) \n▁ xxunk in $ xxunk ) \n▁ { \n▁ $ xxunk $ xxunk + " ; " \n▁ } \n▁ # write - host " permissions : " $ xxunk \n\n▁ " $ ( $ xxunk</td>
#       <td>} \n\n▁ # xxmaj check xxmaj web xxmaj application xxmaj policies \n▁ $ xxunk get - xxunk $ xxunk \n\n▁ foreach ( $ policy in $ xxunk ) \n▁ { \n▁ # xxmaj check if the search users is member of the group \n▁ xxunk -eq $ searchuser ) \n▁ { \n▁ # write - host $ xxunk \n▁ $ xxunk ( ) \n▁ xxunk in $ xxunk ) \n▁ { \n▁ $ xxunk $ xxunk + " ; " \n▁ } \n▁ # write - host " permissions : " $ xxunk \n\n▁ " $ ( $ xxunk )</td>
#       <td>xxfld \n▁ xxfld xxmaj this the if xxmaj application xxmaj manager \n▁ # ( = - xxunk \n▁ xxunk \n▁ # ( $ xxunk as $ xxunk ) \n▁ { \n▁ $ xxmaj the the the user page are already of the user \n▁ xxunk ) $ xxunk ) \n▁ { \n▁ $ xxmaj - host $ xxunk \n▁ $ xxunk = ) ; xxunk ) $ xxunk ) \n▁ { \n▁ $ xxunk = xxunk = xxunk xxunk \n▁ \n▁ } \n▁ } xxmaj - host $ xxunk " " $ xxunk " # $ xxunk xxunk xxunk )</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>7 https : / / stackoverflow.com / users / xxunk xxfld 8 http : / / stackoverflow.com / questions / xxunk / wordpress - custom - taxonomy - page - of - custom - post - type - listing - by - terms xxfld 9 xxup stackoverflow xxfld 10 stackoverflow.com xxbos xxfld 1 xxmaj identifying sequential patterns xxfld 2 i am working with sequence data which are long lists of malware win - api calls . i am trying to cast the problem of identifying ' malware behavior ' into one of finding sequential patterns . i treat each api</td>
#       <td>https : / / stackoverflow.com / users / xxunk xxfld 8 http : / / stackoverflow.com / questions / xxunk / wordpress - custom - taxonomy - page - of - custom - post - type - listing - by - terms xxfld 9 xxup stackoverflow xxfld 10 stackoverflow.com xxbos xxfld 1 xxmaj identifying sequential patterns xxfld 2 i am working with sequence data which are long lists of malware win - api calls . i am trying to cast the problem of identifying ' malware behavior ' into one of finding sequential patterns . i treat each api call</td>
#       <td>xxrep : / / xxunk / users / xxunk xxfld 8 http : / / stackoverflow.com / questions / xxunk / how - app - url - in - in - a - url - page xxfld in - in - user - 9 xxup stackoverflow xxfld 10 stackoverflow.com xxbos xxfld 1 xxmaj how a objects xxfld 2 xxmaj have trying on a of . is a and . the . . xxunk . . xxmaj have trying to get a data with using a xxunk ' ' in a of the the variables . xxmaj have the of in</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>14.04 and run update - grub for it to find the new 14.04 and add it to the grub menu . \n▁ xxfld 6 xxmaj anthon xxfld 7 https : / / unix.stackexchange.com / users / 33055 xxfld 8 http : / / unix.stackexchange.com / questions / xxunk / how - to - install - xxunk - xxunk - the - same - existing - os - in - laptop xxfld 9 xxup technology xxfld 10 unix.stackexchange.com xxbos xxfld 1 jquery xxup ui xxmaj datepicker getdate returns today 's date on inva

# %%
learn.save_encoder('enc1')

# %%
from nbdev.export import notebook2script
notebook2script()
# Out:
# Converted 00_encoder.ipynb.
# Converted 01_decoder.ipynb.
# Converted index.ipynb.
